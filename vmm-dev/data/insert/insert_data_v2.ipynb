# %% [markdown]
# # Insert MJP JSONL data according to the VMM/ELI data model
#
# This notebook reads a JSONL file containing one complete MJP delivery per line and inserts all deliveries into:
#
# ```text
# http://mu.semte.ch/graphs/public
# ```
#
# For every delivery, it creates the following structure:
#
# ```text
# vmm:Aanlevering
# └── eli:has_member → beleidsdoelstelling Work
#     ├── eli:is_realized_by → beleidsdoelstelling Expression
#     └── eli:has_member → actieplan Work
#         ├── eli:is_realized_by → actieplan Expression
#         └── eli:has_member → actie Work
#             └── eli:is_realized_by → actie Expression
# ```
#
# The policy objects and their textual Expressions are separate RDF resources:
#
# - a beleidsdoelstelling is an `eli:ComplexWork`;
# - an actieplan is an `eli:ComplexWork`;
# - an actie is an `eli:Work`;
# - each of these Works has exactly one `eli:Expression`;
# - the delivery itself is a `vmm:Aanlevering`, not an ELI Work or Expression.

# %% [markdown]
# ## 1. Configuration

# %%
from __future__ import annotations

import json
import math
import uuid
from pathlib import Path
from typing import Any, Iterator

import requests


# Direct Virtuoso SPARQL endpoint.
SPARQL_URL = "http://localhost:8890/sparql"

# All MJP records are stored in the shared public graph.
PUBLIC_GRAPH = "http://mu.semte.ch/graphs/public"

# Jobs, Tasks, NodeShapes, DataContainers live here.
HARVESTING_GRAPH = "http://mu.semte.ch/graphs/harvesting"


# The code list for the VAP Klimaatadaptatie model is published as a concept scheme.
CODELIST_URI = "http://data.lblod.gift/id/conceptscheme/vap-klimaatadaptatie"


# One JSON object per line.
MJP_SOURCE_FILE = Path("data/vap_mjp_structured_2.jsonl")

# Set to True to print and validate generated updates without sending them.
DRY_RUN = False

# Optional safety limit. Use None to process the complete JSONL file.
MAX_DELIVERIES: int | None = None

# A plain INSERT is idempotent for unchanged RDF triples.
# Keep this False unless an existing delivery must be fully replaced.
REPLACE_EXISTING_DELIVERIES = False

# URI conventions grounded in the proposed model's `vmm:` namespace and
# instance patterns such as `vmm:actie/{id}`.
VMM_BASE = "http://lblod.data.gift/vocabularies/vmm/"

BODY_URI = "http://data.lblod.info/id/bestuurseenheden/353234a365664e581db5c2f7cc07add2534b47b8e1ab87c821fc6e6365e6bef5"

PREFIXES = """
PREFIX dct:    <http://purl.org/dc/terms/>
PREFIX eli:    <http://data.europa.eu/eli/ontology#>
PREFIX epvoc:  <https://data.europarl.europa.eu/def/epvoc#>
PREFIX mu:     <http://mu.semte.ch/vocabularies/core/>
PREFIX schema: <https://schema.org/>
PREFIX vmm:    <http://lblod.data.gift/vocabularies/vmm/>
PREFIX xsd:    <http://www.w3.org/2001/XMLSchema#>
""".strip()

print("Configuration loaded.")
print(f"Source: {MJP_SOURCE_FILE}")

print(f"Target graph: {PUBLIC_GRAPH}")
print(f"Dry run: {DRY_RUN}")
# Out:
# Configuration loaded.
# Source: data\vap_mjp_structured_2.jsonl
# Target graph: http://mu.semte.ch/graphs/public
# Dry run: False

# %% [markdown]
# ## 2. SPARQL helpers

# %%
def sparql_update(query: str) -> requests.Response:
    """Execute a SPARQL Update against Virtuoso."""
    response = requests.post(
        SPARQL_URL,
        data={"query": query},
        timeout=120,
    )
    response.raise_for_status()
    return response


def sparql_query(query: str) -> list[dict[str, Any]]:
    """Execute a SPARQL SELECT query and return its bindings."""
    response = requests.get(
        SPARQL_URL,
        params={"query": query, "format": "application/sparql-results+json"},
        timeout=120,
    )
    response.raise_for_status()
    return response.json().get("results", {}).get("bindings", [])


def is_blank(value: Any) -> bool:
    if value is None:
        return True
    if isinstance(value, float) and math.isnan(value):
        return True
    return str(value).strip() == ""


def text_value(value: Any) -> str | None:
    """Return a trimmed string, or None for empty/whitespace-only values."""
    if is_blank(value):
        return None
    return str(value).strip()


def first_value(data: dict[str, Any], *keys: str) -> Any:
    """Read the first available key, allowing snake_case and camelCase input."""
    for key in keys:
        if key in data:
            return data[key]
    return None


def sparql_string(value: Any, *, lang: str | None = None) -> str:
    """Encode a Python value as a SPARQL-safe quoted string literal."""
    text = text_value(value)
    if text is None:
        raise ValueError("Cannot serialize a blank value as a required literal.")
    encoded = json.dumps(text, ensure_ascii=False)
    return f"{encoded}@{lang}" if lang else encoded


def sparql_boolean(value: Any) -> str | None:
    """
    Convert source boolean representations to an xsd:boolean lexical form.
    Returns None when the value is absent.
    """
    if is_blank(value):
        return None
    if isinstance(value, bool):
        return "true" if value else "false"
    if isinstance(value, (int, float)) and value in (0, 1):
        return "true" if int(value) == 1 else "false"

    normalized = str(value).strip().lower()
    if normalized in {"true", "1", "yes", "ja"}:
        return "true"
    if normalized in {"false", "0", "no", "nee"}:
        return "false"
    raise ValueError(f"Unsupported boolean value: {value!r}")


def uri(kind: str, source_id: Any) -> str:
    source_id_text = text_value(source_id)
    if source_id_text is None:
        raise ValueError(f"Missing identifier for {kind}.")
    return f"{VMM_BASE}{kind}/{source_id_text}"


def expression_uri(kind: str, source_id: Any) -> str:
    return f"{uri(kind, source_id)}/expression"

# %% [markdown]
# ## 3. Read and validate the JSONL input

# %%
def iter_jsonl(path: Path) -> Iterator[tuple[int, dict[str, Any]]]:
    """Yield `(line_number, object)` for every non-empty JSONL line."""
    with path.open("r", encoding="utf-8") as handle:
        for line_number, raw_line in enumerate(handle, start=1):
            if not raw_line.strip():
                continue
            try:
                record = json.loads(raw_line)
            except json.JSONDecodeError as exc:
                raise ValueError(
                    f"Invalid JSON on line {line_number}: {exc.msg}"
                ) from exc
            if not isinstance(record, dict):
                raise ValueError(
                    f"Line {line_number} must contain a JSON object, "
                    f"not {type(record).__name__}."
                )
            yield line_number, record


def require_id(entity: dict[str, Any], *, kind: str, context: str) -> str:
    identifier = text_value(entity.get("id"))
    if identifier is None:
        raise ValueError(f"{context}: {kind} is missing its `id`.")
    return identifier


def validate_delivery(delivery: dict[str, Any], *, line_number: int) -> dict[str, int]:
    """
    Validate required hierarchy identifiers and return entity counts.
    Empty arrays are allowed, but every present entity must have an ID.
    """
    delivery_id = text_value(delivery.get("id"))
    if delivery_id is None:
        raise ValueError(
            f"Line {line_number}: delivery is missing `id`."
        )

    counts = {
        "aanleveringen": 1,
        "beleidsdoelstellingen": 0,
        "actieplannen": 0,
        "acties": 0,
    }

    seen: dict[str, set[str]] = {
        "beleidsdoelstelling": set(),
        "actieplan": set(),
        "actie": set(),
    }

    strategische_doelstellingen = delivery.get("strategische_doelstellingen", []) or []
    if not isinstance(strategische_doelstellingen, list):
        raise ValueError(
            f"Line {line_number}: `strategische_doelstellingen` must be an array."
        )
    for sd_index, sd in enumerate(strategische_doelstellingen):

        if not isinstance(sd, dict):
            raise ValueError(
                f"Line {line_number}, strategische doelstelling {sd_index}: "
                "expected an object."
            )
        sd_id = require_id(
            sd, kind="strategische_doelstelling", context=f"Line {line_number}",
        )

        beleidsdoelstellingen = sd.get("beleidsdoelstellingen", []) or []

        if not isinstance(beleidsdoelstellingen, list):
            raise ValueError(
                f"Line {line_number}: `beleidsdoelstellingen` must be an array."
            )

        for bd_index, bd in enumerate(beleidsdoelstellingen):
            if not isinstance(bd, dict):
                raise ValueError(
                    f"Line {line_number}, beleidsdoelstelling {bd_index}: "
                    "expected an object."
                )
            bd_id = require_id(
                bd, kind="beleidsdoelstelling", context=f"Line {line_number}",
            )
            if bd_id in seen["beleidsdoelstelling"]:
                raise ValueError(
                    f"Line {line_number}: duplicate beleidsdoelstelling ID {bd_id}."
                )
            seen["beleidsdoelstelling"].add(bd_id)
            counts["beleidsdoelstellingen"] += 1

            actieplannen = bd.get("actieplannen", []) or []
            if not isinstance(actieplannen, list):
                raise ValueError(
                    f"Line {line_number}, beleidsdoelstelling {bd_id}: "
                    "`actieplannen` must be an array."
                )

            for ap_index, ap in enumerate(actieplannen):
                if not isinstance(ap, dict):
                    raise ValueError(
                        f"Line {line_number}, actieplan {ap_index}: "
                        "expected an object."
                    )
                ap_id = require_id(
                    ap, kind="actieplan",
                    context=f"Line {line_number}, beleidsdoelstelling {bd_id}",
                )
                if ap_id in seen["actieplan"]:
                    raise ValueError(
                        f"Line {line_number}: duplicate actieplan ID {ap_id}."
                    )
                seen["actieplan"].add(ap_id)
                counts["actieplannen"] += 1

                acties = ap.get("acties", []) or []
                if not isinstance(acties, list):
                    raise ValueError(
                        f"Line {line_number}, actieplan {ap_id}: "
                        "`acties` must be an array."
                    )

                for action_index, action in enumerate(acties):
                    if not isinstance(action, dict):
                        raise ValueError(
                            f"Line {line_number}, action {action_index}: "
                            "expected an object."
                        )
                    action_id = require_id(
                        action, kind="actie",
                        context=f"Line {line_number}, actieplan {ap_id}",
                    )
                    if action_id in seen["actie"]:
                        raise ValueError(
                            f"Line {line_number}: duplicate action ID {action_id}."
                        )
                    seen["actie"].add(action_id)
                    counts["acties"] += 1

    return counts


if not MJP_SOURCE_FILE.exists():
    raise FileNotFoundError(
        f"JSONL source file not found: {MJP_SOURCE_FILE.resolve()}"
    )

deliveries: list[tuple[int, dict[str, Any]]] = []
total_counts = {
    "aanleveringen": 0,
    "beleidsdoelstellingen": 0,
    "actieplannen": 0,
    "acties": 0,
}

tmp_deliveries = []
for line_number, delivery in iter_jsonl(MJP_SOURCE_FILE):
    tmp_deliveries.append(delivery)
    counts = validate_delivery(delivery, line_number=line_number)
    deliveries.append((line_number, delivery))
    for key, value in counts.items():
        total_counts[key] += value

    if MAX_DELIVERIES is not None and len(deliveries) >= MAX_DELIVERIES:
        break

print(f"Validated {len(deliveries)} JSONL deliveries.")
for key, value in total_counts.items():
    print(f"  {key}: {value}")
# Out:
# Validated 969 JSONL deliveries.
#   aanleveringen: 969
#   beleidsdoelstellingen: 7432
#   actieplannen: 27766
#   acties: 112237

# %%
all_ids_per_type = {
    "strategische_doelstellingen": set(),
    "beleidsdoelstellingen": set(),
    "actieplannen": set(),
    "acties": set(),
}

print("\nCounting unique IDs in new version...\n")
for delivery in tmp_deliveries:
    for sd in delivery.get("strategische_doelstellingen", []):
        all_ids_per_type["strategische_doelstellingen"].add(sd["id"])
        for bd in sd.get("beleidsdoelstellingen", []):
            all_ids_per_type["beleidsdoelstellingen"].add(bd["id"])
            for ap in bd.get("actieplannen", []):
                all_ids_per_type["actieplannen"].add(ap["id"])
                for action in ap.get("acties", []):
                    all_ids_per_type["acties"].add(action["id"])

for entity_type, ids in all_ids_per_type.items():
    print(f"Unique {entity_type}: {len(ids)}")



olde_version_path = Path("data/vap_mjp_structured.jsonl")
older_version = []
if olde_version_path.exists():
    for line_number, delivery in iter_jsonl(olde_version_path):
        older_version.append(delivery)
    print(f"Loaded {len(older_version)} deliveries from older version.")

all_ids_per_type_old = {
    "beleidsdoelstellingen": set(),
    "actieplannen": set(),
    "acties": set(),
}

print("\nCounting unique IDs in older version...\n")
for delivery in older_version:
        for bd in delivery.get("beleidsdoelstellingen", []):
            all_ids_per_type_old["beleidsdoelstellingen"].add(bd["id"])
            for ap in bd.get("actieplannen", []):
                all_ids_per_type_old["actieplannen"].add(ap["id"])
                for action in ap.get("acties", []):
                    all_ids_per_type_old["acties"].add(action["id"])


for entity_type, ids in all_ids_per_type_old.items():
    print(f"Unique {entity_type} in older version: {len(ids)}")


print("\nComparing older version with new version...\n")
# check if all ids in the older version are present in the new version
for entity_type, ids in all_ids_per_type_old.items():
    missing_ids = ids - all_ids_per_type[entity_type]
    if missing_ids:
        print(f"Missing {entity_type} in new version: {len(missing_ids)}")

    else:
        print(f"All {entity_type} from older version are present in the new version.")
# Out:
# Counting unique IDs in new version...
#
# Unique strategische_doelstellingen: 884
# Unique beleidsdoelstellingen: 7432
# Unique actieplannen: 27766
# Unique acties: 112237
# Loaded 525 deliveries from older version.
#
# Counting unique IDs in older version...
#
# Unique beleidsdoelstellingen in older version: 4014
# Unique actieplannen in older version: 14752
# Unique acties in older version: 59015
#
# Comparing older version with new version...
#
# Missing beleidsdoelstellingen in new version: 46
# Missing actieplannen in new version: 130
# Missing acties in new version: 497

# %% [markdown]
# ## 4. JSON-to-RDF transformation
#
# Builds all triples inline per delivery — no sub-functions for individual expressions or works.
# For each entity (beleidsdoelstelling, actieplan, actie) the Work and its Expression triples
# are constructed right in the loop.

# %%
def resource_uuid(resource_uri: str) -> str:
    """Generate a deterministic UUID for any resource based on its URI."""
    return str(uuid.uuid5(uuid.NAMESPACE_URL, resource_uri))


def delivery_to_triples(delivery: dict[str, Any]) -> list[str]:
    """
    Convert one complete MJP JSON delivery into a flat list of triple strings.

    Mapped top-level fields: aanlevering_id, rapportjaar.
    Skipped (no model predicates yet): type_rapport, status, bestuur.
    """
    triples: list[str] = []
    uris: dict[str, list[str]] = {}

    delivery_id = text_value(delivery.get("id"))
    assert delivery_id is not None

    delivery_uri = uri("aanlevering", delivery_id)
    triples.append(f"<{delivery_uri}> a vmm:Aanlevering .")
    triples.append(f"<{delivery_uri}> mu:uuid {sparql_string(resource_uuid(delivery_uri))} .")
    triples.append(f"<{delivery_uri}> dct:identifier {sparql_string(delivery_id)} .")

    report_year = text_value(delivery.get("rapportjaar"))
    if report_year is not None:
        triples.append(f"<{delivery_uri}> schema:datePublished {sparql_string(report_year)} .")

    # --- Strategische doelstellingen (ComplexWork) ---
    for sd in delivery.get("strategische_doelstellingen", []) or []:
        sd_id = text_value(sd["id"])
        assert sd_id is not None

        sd_work = uri("strategische_doelstelling", sd_id)
        sd_expr = expression_uri("strategische_doelstelling", sd_id)

        if "sd_work" not in uris:
            uris["sd_work"] = []
        if "sd_expr" not in uris:
            uris["sd_expr"] = []
        uris["sd_work"].append(sd_work)
        uris["sd_expr"].append(sd_expr)


        ## Expression
        triples.append(f"<{sd_expr}> a eli:Expression, vmm:StrategischeDoelstelling .")
        triples.append(f"<{sd_expr}> mu:uuid {sparql_string(resource_uuid(sd_expr))} .")
        for pred, val in [
            ("eli:title", "strategische doelstelling [" + sd.get("code") + "]"),
            ("schema:code", sd.get("code")),
            ("eli:description", first_value(sd, "korte_omschrijving", "korteOmschrijving")),
            ("epvoc:expressionContent", first_value(sd, "lange_omschrijving", "langeOmschrijving")),
            ("schema:comment", sd.get("commentaar")),
            ("schema:review", sd.get("evaluatie"))
        ]:
            text = text_value(val)
            if text is not None:
                triples.append(f"<{sd_expr}> {pred} {sparql_string(text)} .")

        priority = sparql_boolean(sd.get("prioritair"))
        if priority is not None:
            triples.append(f'<{sd_expr}> vmm:prioritair "{priority}"^^xsd:boolean .')


        # Link expression → owning body and passed_by
        # triples.append(f"<{sd_expr}> <http://mu.semte.ch/vocabularies/ext/owningBody> <{BODY_URI}> .")
        # triples.append(f"<{sd_expr}> eli:passed_by <{BODY_URI}> .")

        # Work
        triples.append(f"<{sd_work}> a eli:ComplexWork .")
        triples.append(f"<{sd_work}> mu:uuid {sparql_string(resource_uuid(sd_work))} .")
        triples.append(f"<{sd_work}> dct:identifier {sparql_string(sd_id)} .")
        triples.append(f"<{sd_work}> eli:work_type vmm:StrategischeDoelstelling .")
        triples.append(f"<{sd_work}> eli:is_realized_by <{sd_expr}> .")

        # Link delivery → strategische doelstelling
        triples.append(f"<{delivery_uri}> dct:hasPart <{sd_work}> .")

        # --- Beleidsdoelstellingen (ComplexWork) ---
        for bd in sd.get("beleidsdoelstellingen", []) or []:
            bd_id = text_value(bd["id"])
            assert bd_id is not None

            bd_work = uri("beleidsdoelstelling", bd_id)
            bd_expr = expression_uri("beleidsdoelstelling", bd_id)

            if "bd_work" not in uris:
                uris["bd_work"] = []
            if "bd_expr" not in uris:
                uris["bd_expr"] = []
            uris["bd_work"].append(bd_work)
            uris["bd_expr"].append(bd_expr)

            # Expression
            triples.append(f"<{bd_expr}> a eli:Expression, vmm:Beleidsdoelstelling .")
            triples.append(f"<{bd_expr}> mu:uuid {sparql_string(resource_uuid(bd_expr))} .")
            for pred, val in [
                ("eli:title", "beleidsdoelstelling [" + bd.get("code") + "]"),
                ("schema:code", bd.get("code")),
                ("eli:description", first_value(bd, "korte_omschrijving", "korteOmschrijving")),
                ("epvoc:expressionContent", first_value(bd, "lange_omschrijving", "langeOmschrijving")),
                ("schema:comment", bd.get("commentaar")),
                ("schema:review", bd.get("evaluatie")),
            ]:
                text = text_value(val)
                if text is not None:
                    triples.append(f"<{bd_expr}> {pred} {sparql_string(text)} .")
            priority = sparql_boolean(bd.get("prioritair"))
            if priority is not None:
                triples.append(f'<{bd_expr}> vmm:prioritair "{priority}"^^xsd:boolean .')


            # Link expression → owning body and passed_by
            # triples.append(f"<{bd_expr}> <http://mu.semte.ch/vocabularies/ext/owningBody> <{BODY_URI}> .")
            # triples.append(f"<{bd_expr}> eli:passed_by <{BODY_URI}> .")

            # Work
            triples.append(f"<{bd_work}> a eli:ComplexWork .")
            triples.append(f"<{bd_work}> mu:uuid {sparql_string(resource_uuid(bd_work))} .")
            triples.append(f"<{bd_work}> dct:identifier {sparql_string(bd_id)} .")
            triples.append(f"<{bd_work}> eli:work_type vmm:Beleidsdoelstelling .")
            triples.append(f"<{bd_work}> eli:is_realized_by <{bd_expr}> .")

            # Link delivery → beleidsdoelstelling
            triples.append(f"<{sd_work}> eli:has_member <{bd_work}> .")

            # --- Actieplannen (ComplexWork) ---
            for ap in bd.get("actieplannen", []) or []:
                ap_id = text_value(ap["id"])
                assert ap_id is not None

                ap_work = uri("actieplan", ap_id)
                ap_expr = expression_uri("actieplan", ap_id)

                if "ap_work" not in uris:
                    uris["ap_work"] = []
                if "ap_expr" not in uris:
                    uris["ap_expr"] = []
                uris["ap_work"].append(ap_work)
                uris["ap_expr"].append(ap_expr)

                # Expression
                triples.append(f"<{ap_expr}> a eli:Expression, vmm:Actieplan .")
                triples.append(f"<{ap_expr}> mu:uuid {sparql_string(resource_uuid(ap_expr))} .")
                for pred, val in [
                    ("eli:title", "actieplan [" + ap.get("code") + "]"),
                    ("schema:code", ap.get("code")),
                    ("eli:description", first_value(ap, "korte_omschrijving", "korteOmschrijving")),
                    ("epvoc:expressionContent", first_value(ap, "lange_omschrijving", "langeOmschrijving")),
                    ("schema:comment", ap.get("commentaar")),
                    ("schema:review", ap.get("evaluatie")),

                ]:
                    text = text_value(val)
                    if text is not None:
                        triples.append(f"<{ap_expr}> {pred} {sparql_string(text)} .")
                priority = sparql_boolean(ap.get("prioritair"))

                ## Link expression → owning body and passed_by
                # triples.append(f"<{ap_expr}> <http://mu.semte.ch/vocabularies/ext/owningBody> <{BODY_URI}> .")
                # triples.append(f"<{ap_expr}> eli:passed_by <{BODY_URI}> .")

                # Work
                triples.append(f"<{ap_work}> a eli:ComplexWork .")
                triples.append(f"<{ap_work}> mu:uuid {sparql_string(resource_uuid(ap_work))} .")
                triples.append(f"<{ap_work}> dct:identifier {sparql_string(ap_id)} .")
                triples.append(f"<{ap_work}> eli:work_type vmm:Actieplan .")
                triples.append(f"<{ap_work}> eli:is_realized_by <{ap_expr}> .")

                # Link beleidsdoelstelling → actieplan
                triples.append(f"<{bd_work}> eli:has_member <{ap_work}> .")
                triples.append(f"<{delivery_uri}> dct:hasPart <{ap_work}> .")

                # --- Acties (Work) ---
                for action in ap.get("acties", []) or []:
                    act_id = text_value(action["id"])
                    assert act_id is not None

                    act_work = uri("actie", act_id)
                    act_expr = expression_uri("actie", act_id)

                    if "act_work" not in uris:
                        uris["act_work"] = []
                    if "act_expr" not in uris:
                        uris["act_expr"] = []
                    uris["act_work"].append(act_work)
                    uris["act_expr"].append(act_expr)

                    # Expression
                    triples.append(f"<{act_expr}> a eli:Expression, vmm:Actie .")
                    triples.append(f"<{act_expr}> mu:uuid {sparql_string(resource_uuid(act_expr))} .")
                    for pred, val in [
                        ("eli:title", "actie [" + action.get("code") + "]"),
                        ("schema:code", action.get("code")),
                        ("eli:description", first_value(action, "korte_omschrijving", "korteOmschrijving")),
                        ("epvoc:expressionContent", first_value(action, "lange_omschrijving", "langeOmschrijving")),
                        ("schema:comment", action.get("commentaar")),
                        ("schema:review", action.get("evaluatie")),
                    ]:
                        text = text_value(val)
                        if text is not None:
                            triples.append(f"<{act_expr}> {pred} {sparql_string(text)} .")
                    priority = sparql_boolean(action.get("prioritair"))

                    ## Link expression → owning body and passed_by
                    # triples.append(f"<{act_expr}> <http://mu.semte.ch/vocabularies/ext/owningBody> <{BODY_URI}> .")
                    # triples.append(f"<{act_expr}> eli:passed_by <{BODY_URI}> .")

                    # Work
                    triples.append(f"<{act_work}> a eli:Work .")
                    triples.append(f"<{act_work}> mu:uuid {sparql_string(resource_uuid(act_work))} .")
                    triples.append(f"<{act_work}> dct:identifier {sparql_string(act_id)} .")
                    triples.append(f"<{act_work}> eli:work_type vmm:Actie .")
                    triples.append(f"<{act_work}> eli:is_realized_by <{act_expr}> .")

                    # Link actieplan → actie
                    triples.append(f"<{ap_work}> eli:has_member <{act_work}> .")
                    triples.append(f"<{delivery_uri}> dct:hasPart <{act_work}> .")

                    #Validation check if 'aanlevering_id' matches the delivery_id
                    if str(action.get("aanlevering_id")) != str(delivery_id):
                        print(f"Warning: action {act_id} has aanlevering_id {action.get('aanlevering_id')} which does not match delivery_id {delivery_id}")

    return triples, uris


def build_insert_query(triples: list[str]) -> str:
    body = "\n    ".join(triples)
    return f"""
{PREFIXES}

INSERT DATA {{
  GRAPH <{PUBLIC_GRAPH}> {{
    {body}
  }}
}}
""".strip()


# Generate triples for every delivery.
generated_updates: list[tuple[int, str, list[str]]] = []
all_uris: dict[str, list[str]] = {}

for line_number, delivery in deliveries:
    delivery_id = text_value(delivery["id"])
    assert delivery_id is not None
    triples, uris = delivery_to_triples(delivery)
    generated_updates.append((line_number, delivery_id, triples))
    for key, value in uris.items():
        if key not in all_uris:
            all_uris[key] = []
        all_uris[key].extend(value)

print(f"Generated {len(generated_updates)} SPARQL updates.")
if generated_updates:
    first_line, first_id, first_triples = generated_updates[0]
    print(
        f"First delivery: line {first_line}, ID {first_id}, "
        f"{len(first_triples)} triples"
    )

    print("\nPreview:\n")
    print(build_insert_query(first_triples))
# Out:
# Generated 969 SPARQL updates.
# First delivery: line 1, ID 10000158105, 290 triples
#
# Preview:
#
# PREFIX dct:    <http://purl.org/dc/terms/>
# PREFIX eli:    <http://data.europa.eu/eli/ontology#>
# PREFIX epvoc:  <https://data.europarl.europa.eu/def/epvoc#>
# PREFIX mu:     <http://mu.semte.ch/vocabularies/core/>
# PREFIX schema: <https://schema.org/>
# PREFIX vmm:    <http://lblod.data.gift/vocabularies/vmm/>
# PREFIX xsd:    <http://www.w3.org/2001/XMLSchema#>
#
# INSERT DATA {
#   GRAPH <http://mu.semte.ch/graphs/public> {
#     <http://lblod.data.gift/vocabularies/vmm/aanlevering/10000158105> a vmm:Aanlevering .
#     <http://lblod.data.gift/vocabularies/vmm/aanlevering/10000158105> mu:uuid "2b8d6328-f75d-5655-a5ab-472fecc248f6" .
#     <http://lblod.data.gift/vocabularies/vmm/aanlevering/10000158105> dct:identifier "10000158105" .
#     <http://lblod.data.gift/vocabularies/vmm/aanlevering/10000158105> schema:datePublished "2026" .
#     <http://lblod.data.gift/vocabularies/vmm/strategische_doelstelling/2315855/expression> a eli:Expression, vmm:StrategischeDoelstelling .
#     <http://lblod.data.gift/vocabularies/vmm/strategische_doelstelling/2315855/expression> mu:uuid "4bd9db90-2b89-5216-8ced-be9661573679" .
#     <http://lblod.data.gift/vocabularies/vmm/strategische_doelstelling/2315855/expression> eli:title "strategische doelstelling [Hove]" .
#     <http://lblod.data.gift/vocabularies/vmm/strategische_doelstelling/2315855/expression> schema:code "Hove" .
#     <http://lblod.data.gift/vocabularies/vmm/strategische_doelstelling/2315855/expression> eli:description "Want het dorp is een wereld." .
#     <http://lblod.data.gift/vocabularies/vmm/strategische_doelstelling/2315855/expression> epvoc:expressionContent "Want het dorp is een wereld." .
#     <http://lblod.data.gift/vocabularies/vmm/strategische_doelstelling/2315855/expression> vmm:prioritair "false"^^xsd:boolean .
#     <http://lblod.data.gift/vocabularies/vmm/strategische_doelstelling/2315855> a eli:ComplexWork .
#     <http://lblod.data.gift/vocabularies/vmm/strategische_doelstelling/2315855> mu:uuid "f42a54d1-ac58-55e1-aead-76c9b0a102d9" .
#     <http://lblod.data.gift/vocabularies/vmm/strategische_doelstelling/2315855> dct:identifier "2315855" .
#     <http://lblod.data.gift/vocabularies/vmm/strategische_doelstelling/2315855> eli:work_type vmm:StrategischeDoelstelling .
#     <http://lblod.data.gift/vocabularies/vmm/strategische_doelstelling/2315855> eli:is_realized_by <http://lblod.data.gift/vocabularies/vmm/strategische_doelstelling/2315855/expression> .
#     <http://lblod.data.gift/vocabularies/vmm/aanlevering/10000158105> dct:hasPart <http://lblod.data.gift/vocabularies/vmm/strategische_doelstelling/2315855> .
#     <http://lblod.data.gift/vocabularies/vmm/beleidsdoelstelling/2315856/expression> a eli:Expression, vmm:Beleidsdoelstelling .
#     <http://lblod.data.gift/vocabularies/vmm/beleidsdoelstelling/2315856/expression> mu:uuid "616cc7a9-704a-5306-9fc9-33f11f753e35" .
#     <http://lblod.data.gift/vocabularies/vmm/beleidsdoelstelling/2315856/expression> eli:title "beleidsdoelstelling [BD000004]" .
#     <http://lblod.data.gift/vocabularies/vmm/beleidsdoelstelling/2315856/expression> schema:code "BD000004" .
#     <http://lblod.data.gift/vocabularies/vmm/beleidsdoelstelling/2315856/expression> eli:description "Het AGB sport en ontspanning" .
#     <http://lblod.data.gift/vocabularies/vmm/beleidsdoelstelling/2315856/expression> epvoc:expressionContent "Het AGB sport en ontspanning zorgt voor het beheer, de exploitatie, de rendabilisering en de valorisering van infrastructuren bestemd voor sportieve activiteiten of ontspanningsdoeleinden." .
#     <http://lblod.data.gift/vocabularies/vmm/beleidsdoelstelling/2315856/expression> vmm:prioritair "false"^^xsd:boolean .
#     <http://lblod.data.gift/vocabularies/vmm/beleidsdoelstelling/2315856> a eli:ComplexWork .
#     <http://lblod.data.gift/vocabularies/vmm/beleidsdoelstelling/2315856> mu:uuid "2b1598bf-bac3-566d-940b-2e13df3da42e" .
#     <http://lblod.data.gift/vocabularies/vmm/beleidsdoelstelling/2315856> dct:identifier "2315856" .
#     <http://lblod.data.gift/vocabularies/vmm/beleidsdoelstelling/2315856> eli:work_type vmm:Beleidsdoelstelling .
#     <http://lblod.data.gift/vocabularies/vmm/beleidsdoelstelling/2315856> eli:is_realized_by <http://lblod.data.gift/vocabularies/vmm/beleidsdoelstelling/2315856/expression> .
#     <http://lblod.data.gift/vocabularies/vmm/strategische_doelstelling/2315855> eli:has_member <http://lblod.data.gift/vocabularies/vmm/beleidsdoelstelling/2315856> .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270327/expression> a eli:Expression, vmm:Actieplan .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270327/expression> mu:uuid "62be50a9-7f49-5221-ae6e-3d229a3b03a8" .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270327/expression> eli:title "actieplan [AP000031]" .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270327/expression> schema:code "AP000031" .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270327/expression> eli:description "Aanleggen van nieuwe accommodatie." .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270327/expression> epvoc:expressionContent "Aanleggen van nieuwe accommodatie." .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270327> a eli:ComplexWork .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270327> mu:uuid "ab38fc38-2cbe-5182-bcb1-9d05d07b6b4b" .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270327> dct:identifier "5270327" .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270327> eli:work_type vmm:Actieplan .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270327> eli:is_realized_by <http://lblod.data.gift/vocabularies/vmm/actieplan/5270327/expression> .
#     <http://lblod.data.gift/vocabularies/vmm/beleidsdoelstelling/2315856> eli:has_member <http://lblod.data.gift/vocabularies/vmm/actieplan/5270327> .
#     <http://lblod.data.gift/vocabularies/vmm/aanlevering/10000158105> dct:hasPart <http://lblod.data.gift/vocabularies/vmm/actieplan/5270327> .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633584/expression> a eli:Expression, vmm:Actie .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633584/expression> mu:uuid "a6c81d7f-0507-5e58-aeca-5fc995a4ca88" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633584/expression> eli:title "actie [AC000198]" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633584/expression> schema:code "AC000198" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633584/expression> eli:description "Aankoop schrobzuigmachine JOC" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633584/expression> epvoc:expressionContent "Aankoop schrobzuigmachine voor dagelijks onderhoud jeugdontmoetingscentrum" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633584> a eli:Work .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633584> mu:uuid "5a0b4316-3d8f-58f9-982e-556f03b5dc02" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633584> dct:identifier "14633584" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633584> eli:work_type vmm:Actie .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633584> eli:is_realized_by <http://lblod.data.gift/vocabularies/vmm/actie/14633584/expression> .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270327> eli:has_member <http://lblod.data.gift/vocabularies/vmm/actie/14633584> .
#     <http://lblod.data.gift/vocabularies/vmm/aanlevering/10000158105> dct:hasPart <http://lblod.data.gift/vocabularies/vmm/actie/14633584> .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633581/expression> a eli:Expression, vmm:Actie .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633581/expression> mu:uuid "46a07414-f24a-51ac-9224-ff153c217403" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633581/expression> eli:title "actie [AC000176]" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633581/expression> schema:code "AC000176" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633581/expression> eli:description "Aanleg kunstgrasveld en renovatie sportterreinen site L. Dumortierstraat." .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633581/expression> epvoc:expressionContent "Aanleg kunstgrasveld en renovatie sportterreinen site L. Dumortierstraat." .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633581> a eli:Work .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633581> mu:uuid "4a3bdb2e-3659-569f-8dba-957d13b958de" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633581> dct:identifier "14633581" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633581> eli:work_type vmm:Actie .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633581> eli:is_realized_by <http://lblod.data.gift/vocabularies/vmm/actie/14633581/expression> .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270327> eli:has_member <http://lblod.data.gift/vocabularies/vmm/actie/14633581> .
#     <http://lblod.data.gift/vocabularies/vmm/aanlevering/10000158105> dct:hasPart <http://lblod.data.gift/vocabularies/vmm/actie/14633581> .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633582/expression> a eli:Expression, vmm:Actie .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633582/expression> mu:uuid "ad8aa8ea-cdc9-52ec-9691-73801a1bd751" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633582/expression> eli:title "actie [AC000177]" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633582/expression> schema:code "AC000177" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633582/expression> eli:description "Zoeken naar subsidiemogelijkheden voor het verbeteren van de sportinfrastructuur." .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633582/expression> epvoc:expressionContent "Zoeken naar subsidiemogelijkheden voor het verbeteren van de sportinfrastructuur." .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633582> a eli:Work .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633582> mu:uuid "22954a0c-bbb3-50b4-a89f-d2379c6b7e9f" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633582> dct:identifier "14633582" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633582> eli:work_type vmm:Actie .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633582> eli:is_realized_by <http://lblod.data.gift/vocabularies/vmm/actie/14633582/expression> .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270327> eli:has_member <http://lblod.data.gift/vocabularies/vmm/actie/14633582> .
#     <http://lblod.data.gift/vocabularies/vmm/aanlevering/10000158105> dct:hasPart <http://lblod.data.gift/vocabularies/vmm/actie/14633582> .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633583/expression> a eli:Expression, vmm:Actie .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633583/expression> mu:uuid "fdc03946-ab84-561c-9bd3-055aa9323a2e" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633583/expression> eli:title "actie [AC000187]" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633583/expression> schema:code "AC000187" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633583/expression> eli:description "Aankoop mini tractor voor dagelijks onderhoud kunstgrasveld." .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633583/expression> epvoc:expressionContent "Aankoop mini tractor voor dagelijks onderhoud kunstgrasveld." .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633583> a eli:Work .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633583> mu:uuid "78010186-dee0-537b-955d-7980f8a4d5b1" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633583> dct:identifier "14633583" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633583> eli:work_type vmm:Actie .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633583> eli:is_realized_by <http://lblod.data.gift/vocabularies/vmm/actie/14633583/expression> .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270327> eli:has_member <http://lblod.data.gift/vocabularies/vmm/actie/14633583> .
#     <http://lblod.data.gift/vocabularies/vmm/aanlevering/10000158105> dct:hasPart <http://lblod.data.gift/vocabularies/vmm/actie/14633583> .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270328/expression> a eli:Expression, vmm:Actieplan .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270328/expression> mu:uuid "561ac13a-6f76-5066-8bf3-c3f966901688" .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270328/expression> eli:title "actieplan [AP000032]" .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270328/expression> schema:code "AP000032" .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270328/expression> eli:description "Optimaliseren van de bestaande accommodatie." .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270328/expression> epvoc:expressionContent "Optimaliseren van de bestaande accommodatie." .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270328> a eli:ComplexWork .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270328> mu:uuid "b55b5837-8027-52a6-86a1-a6a5150fd43e" .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270328> dct:identifier "5270328" .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270328> eli:work_type vmm:Actieplan .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270328> eli:is_realized_by <http://lblod.data.gift/vocabularies/vmm/actieplan/5270328/expression> .
#     <http://lblod.data.gift/vocabularies/vmm/beleidsdoelstelling/2315856> eli:has_member <http://lblod.data.gift/vocabularies/vmm/actieplan/5270328> .
#     <http://lblod.data.gift/vocabularies/vmm/aanlevering/10000158105> dct:hasPart <http://lblod.data.gift/vocabularies/vmm/actieplan/5270328> .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633591/expression> a eli:Expression, vmm:Actie .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633591/expression> mu:uuid "9aa819d6-ccce-5048-9062-edf96a89a593" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633591/expression> eli:title "actie [AC000189]" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633591/expression> schema:code "AC000189" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633591/expression> eli:description "Herstelling elektrische installaties Hove Sport" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633591/expression> epvoc:expressionContent "Herstelling elektrische installaties Hove Sport" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633591> a eli:Work .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633591> mu:uuid "64c3974b-52ef-5bb7-ba7b-450574cf10d8" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633591> dct:identifier "14633591" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633591> eli:work_type vmm:Actie .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633591> eli:is_realized_by <http://lblod.data.gift/vocabularies/vmm/actie/14633591/expression> .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270328> eli:has_member <http://lblod.data.gift/vocabularies/vmm/actie/14633591> .
#     <http://lblod.data.gift/vocabularies/vmm/aanlevering/10000158105> dct:hasPart <http://lblod.data.gift/vocabularies/vmm/actie/14633591> .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633596/expression> a eli:Expression, vmm:Actie .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633596/expression> mu:uuid "d7e04fe3-4025-5ba7-b6c7-1391bdf108ec" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633596/expression> eli:title "actie [AC000201]" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633596/expression> schema:code "AC000201" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633596/expression> eli:description "Renovatie jeugdlokalen Sportpark" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633596/expression> epvoc:expressionContent "Renovatie jeugdlokalen Sportpark" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633596> a eli:Work .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633596> mu:uuid "c0533ee8-ab80-566e-b157-5c6ce9f713aa" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633596> dct:identifier "14633596" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633596> eli:work_type vmm:Actie .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633596> eli:is_realized_by <http://lblod.data.gift/vocabularies/vmm/actie/14633596/expression> .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270328> eli:has_member <http://lblod.data.gift/vocabularies/vmm/actie/14633596> .
#     <http://lblod.data.gift/vocabularies/vmm/aanlevering/10000158105> dct:hasPart <http://lblod.data.gift/vocabularies/vmm/actie/14633596> .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633595/expression> a eli:Expression, vmm:Actie .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633595/expression> mu:uuid "8118926d-6e73-55c9-94bd-5a87edc4d8f5" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633595/expression> eli:title "actie [AC000200]" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633595/expression> schema:code "AC000200" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633595/expression> eli:description "Maaidek Schell" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633595/expression> epvoc:expressionContent "Aankoop maaidek Schell grasmaaier" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633595> a eli:Work .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633595> mu:uuid "061ee963-0ebd-5db4-b280-9b4624a3b8d9" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633595> dct:identifier "14633595" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633595> eli:work_type vmm:Actie .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633595> eli:is_realized_by <http://lblod.data.gift/vocabularies/vmm/actie/14633595/expression> .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270328> eli:has_member <http://lblod.data.gift/vocabularies/vmm/actie/14633595> .
#     <http://lblod.data.gift/vocabularies/vmm/aanlevering/10000158105> dct:hasPart <http://lblod.data.gift/vocabularies/vmm/actie/14633595> .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633585/expression> a eli:Expression, vmm:Actie .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633585/expression> mu:uuid "d7fd9141-0b92-5836-9fe4-5d590abec285" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633585/expression> eli:title "actie [AC000178]" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633585/expression> schema:code "AC000178" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633585/expression> eli:description "Vernieuwen goederenlift cafetaria Sportpark Hove." .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633585/expression> epvoc:expressionContent "Vernieuwen goederenlift cafetaria Sportpark Hove." .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633585> a eli:Work .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633585> mu:uuid "474ae124-bbed-594d-910e-908187abd8b2" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633585> dct:identifier "14633585" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633585> eli:work_type vmm:Actie .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633585> eli:is_realized_by <http://lblod.data.gift/vocabularies/vmm/actie/14633585/expression> .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270328> eli:has_member <http://lblod.data.gift/vocabularies/vmm/actie/14633585> .
#     <http://lblod.data.gift/vocabularies/vmm/aanlevering/10000158105> dct:hasPart <http://lblod.data.gift/vocabularies/vmm/actie/14633585> .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633587/expression> a eli:Expression, vmm:Actie .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633587/expression> mu:uuid "0d3e718d-aad1-56ff-bf9c-4a35a3cf75b3" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633587/expression> eli:title "actie [AC000180]" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633587/expression> schema:code "AC000180" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633587/expression> eli:description "AGB Hove vernieuwt zijn skatepark" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633587/expression> epvoc:expressionContent "AGB Hove vernieuwt zijn skatepark" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633587> a eli:Work .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633587> mu:uuid "6d419be3-2700-58f9-87bc-8708a7566086" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633587> dct:identifier "14633587" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633587> eli:work_type vmm:Actie .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633587> eli:is_realized_by <http://lblod.data.gift/vocabularies/vmm/actie/14633587/expression> .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270328> eli:has_member <http://lblod.data.gift/vocabularies/vmm/actie/14633587> .
#     <http://lblod.data.gift/vocabularies/vmm/aanlevering/10000158105> dct:hasPart <http://lblod.data.gift/vocabularies/vmm/actie/14633587> .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633589/expression> a eli:Expression, vmm:Actie .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633589/expression> mu:uuid "b7c3caa7-68f3-5781-92a3-10475ac8b0c4" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633589/expression> eli:title "actie [AC000182]" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633589/expression> schema:code "AC000182" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633589/expression> eli:description "Vernieuwen van de verlichting van het natuurgrasveld aan het Sportpark." .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633589/expression> epvoc:expressionContent "Vernieuwen van de verlichting van het natuurgrasveld aan het Sportpark." .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633589> a eli:Work .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633589> mu:uuid "072f8d50-4c1e-5b78-bcf3-04f87f45b601" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633589> dct:identifier "14633589" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633589> eli:work_type vmm:Actie .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633589> eli:is_realized_by <http://lblod.data.gift/vocabularies/vmm/actie/14633589/expression> .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270328> eli:has_member <http://lblod.data.gift/vocabularies/vmm/actie/14633589> .
#     <http://lblod.data.gift/vocabularies/vmm/aanlevering/10000158105> dct:hasPart <http://lblod.data.gift/vocabularies/vmm/actie/14633589> .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633590/expression> a eli:Expression, vmm:Actie .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633590/expression> mu:uuid "e62a5176-1fc8-5cce-924f-4cd0f9ed6d4c" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633590/expression> eli:title "actie [AC000183]" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633590/expression> schema:code "AC000183" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633590/expression> eli:description "Vernieuwen van de rainmobiel voor het grasveld van het Sportpark." .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633590/expression> epvoc:expressionContent "Vernieuwen van de rainmobiel voor het grasveld van het Sportpark." .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633590> a eli:Work .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633590> mu:uuid "ac362a8c-fbe0-5098-a6ac-67fe41b5ce92" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633590> dct:identifier "14633590" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633590> eli:work_type vmm:Actie .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633590> eli:is_realized_by <http://lblod.data.gift/vocabularies/vmm/actie/14633590/expression> .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270328> eli:has_member <http://lblod.data.gift/vocabularies/vmm/actie/14633590> .
#     <http://lblod.data.gift/vocabularies/vmm/aanlevering/10000158105> dct:hasPart <http://lblod.data.gift/vocabularies/vmm/actie/14633590> .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633586/expression> a eli:Expression, vmm:Actie .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633586/expression> mu:uuid "a57956e2-414b-59d0-8f86-688b97889138" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633586/expression> eli:title "actie [AC000179]" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633586/expression> schema:code "AC000179" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633586/expression> eli:description "Plaatsing van extra vluchtdeuren aan het JOC" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633586/expression> epvoc:expressionContent "Plaatsing van extra vluchtdeuren aan het JOC" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633586> a eli:Work .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633586> mu:uuid "ba425169-430b-5b86-b506-82cab8a25c6a" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633586> dct:identifier "14633586" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633586> eli:work_type vmm:Actie .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633586> eli:is_realized_by <http://lblod.data.gift/vocabularies/vmm/actie/14633586/expression> .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270328> eli:has_member <http://lblod.data.gift/vocabularies/vmm/actie/14633586> .
#     <http://lblod.data.gift/vocabularies/vmm/aanlevering/10000158105> dct:hasPart <http://lblod.data.gift/vocabularies/vmm/actie/14633586> .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633588/expression> a eli:Expression, vmm:Actie .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633588/expression> mu:uuid "bd6a9e28-4a11-5e2e-8acc-e2e4f33f7220" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633588/expression> eli:title "actie [AC000181]" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633588/expression> schema:code "AC000181" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633588/expression> eli:description "Klimatisatie in de sporthal optimaliseren." .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633588/expression> epvoc:expressionContent "Klimatisatie in de sporthal optimaliseren." .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633588> a eli:Work .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633588> mu:uuid "1bb2471c-ef7a-5569-82e9-934e1aa0d2e0" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633588> dct:identifier "14633588" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633588> eli:work_type vmm:Actie .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633588> eli:is_realized_by <http://lblod.data.gift/vocabularies/vmm/actie/14633588/expression> .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270328> eli:has_member <http://lblod.data.gift/vocabularies/vmm/actie/14633588> .
#     <http://lblod.data.gift/vocabularies/vmm/aanlevering/10000158105> dct:hasPart <http://lblod.data.gift/vocabularies/vmm/actie/14633588> .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633592/expression> a eli:Expression, vmm:Actie .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633592/expression> mu:uuid "127e3a63-eef9-55db-8417-f929df00fd29" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633592/expression> eli:title "actie [AC000190]" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633592/expression> schema:code "AC000190" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633592/expression> eli:description "Wifi4All: sporthal" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633592/expression> epvoc:expressionContent "Wifi-netwerk sporthal uitbreiden en toegankelijk maken voor de gebruikers" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633592> a eli:Work .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633592> mu:uuid "69324907-2cb5-551b-997d-06129d62ca25" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633592> dct:identifier "14633592" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633592> eli:work_type vmm:Actie .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633592> eli:is_realized_by <http://lblod.data.gift/vocabularies/vmm/actie/14633592/expression> .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270328> eli:has_member <http://lblod.data.gift/vocabularies/vmm/actie/14633592> .
#     <http://lblod.data.gift/vocabularies/vmm/aanlevering/10000158105> dct:hasPart <http://lblod.data.gift/vocabularies/vmm/actie/14633592> .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633593/expression> a eli:Expression, vmm:Actie .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633593/expression> mu:uuid "0b281da3-d65c-5f3a-be0d-3f2e83368c31" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633593/expression> eli:title "actie [AC000192]" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633593/expression> schema:code "AC000192" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633593/expression> eli:description "Renovatie appartement" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633593/expression> epvoc:expressionContent "Renovatie appartement cafetaria sportpark" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633593> a eli:Work .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633593> mu:uuid "e296506a-ac18-574f-bd82-db51895600b9" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633593> dct:identifier "14633593" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633593> eli:work_type vmm:Actie .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633593> eli:is_realized_by <http://lblod.data.gift/vocabularies/vmm/actie/14633593/expression> .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270328> eli:has_member <http://lblod.data.gift/vocabularies/vmm/actie/14633593> .
#     <http://lblod.data.gift/vocabularies/vmm/aanlevering/10000158105> dct:hasPart <http://lblod.data.gift/vocabularies/vmm/actie/14633593> .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633594/expression> a eli:Expression, vmm:Actie .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633594/expression> mu:uuid "4a73cc20-4be4-5aa2-9c31-caf888d8adbb" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633594/expression> eli:title "actie [AC000199]" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633594/expression> schema:code "AC000199" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633594/expression> eli:description "branddetectie Sportpark" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633594/expression> epvoc:expressionContent "Uitbreiding branddetectie Sportpark naar cafetaria" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633594> a eli:Work .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633594> mu:uuid "9d582daf-62cc-59ee-a967-0582bc19ea19" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633594> dct:identifier "14633594" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633594> eli:work_type vmm:Actie .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633594> eli:is_realized_by <http://lblod.data.gift/vocabularies/vmm/actie/14633594/expression> .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270328> eli:has_member <http://lblod.data.gift/vocabularies/vmm/actie/14633594> .
#     <http://lblod.data.gift/vocabularies/vmm/aanlevering/10000158105> dct:hasPart <http://lblod.data.gift/vocabularies/vmm/actie/14633594> .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270329/expression> a eli:Expression, vmm:Actieplan .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270329/expression> mu:uuid "9946b6f7-8d94-58e1-81cb-9df0bba5ae5d" .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270329/expression> eli:title "actieplan [AP000033]" .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270329/expression> schema:code "AP000033" .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270329/expression> eli:description "Dagelijkse werking AGB." .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270329/expression> epvoc:expressionContent "Dagelijkse werking AGB." .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270329> a eli:ComplexWork .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270329> mu:uuid "761c76c6-f507-5c35-a647-4dd055615d92" .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270329> dct:identifier "5270329" .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270329> eli:work_type vmm:Actieplan .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270329> eli:is_realized_by <http://lblod.data.gift/vocabularies/vmm/actieplan/5270329/expression> .
#     <http://lblod.data.gift/vocabularies/vmm/beleidsdoelstelling/2315856> eli:has_member <http://lblod.data.gift/vocabularies/vmm/actieplan/5270329> .
#     <http://lblod.data.gift/vocabularies/vmm/aanlevering/10000158105> dct:hasPart <http://lblod.data.gift/vocabularies/vmm/actieplan/5270329> .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633597/expression> a eli:Expression, vmm:Actie .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633597/expression> mu:uuid "ac6322ec-688b-5914-aee1-ecdb21d8d749" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633597/expression> eli:title "actie [AC000184]" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633597/expression> schema:code "AC000184" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633597/expression> eli:description "Dagelijkse werking AGB." .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633597/expression> epvoc:expressionContent "Dagelijkse werking AGB." .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633597> a eli:Work .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633597> mu:uuid "99307ab8-df5d-51ea-b304-489532c7a444" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633597> dct:identifier "14633597" .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633597> eli:work_type vmm:Actie .
#     <http://lblod.data.gift/vocabularies/vmm/actie/14633597> eli:is_realized_by <http://lblod.data.gift/vocabularies/vmm/actie/14633597/expression> .
#     <http://lblod.data.gift/vocabularies/vmm/actieplan/5270329> eli:has_member <http://lblod.data.gift/vocabularies/vmm/actie/14633597> .
#     <http://lblod.data.gift/vocabularies/vmm/aanlevering/10000158105> dct:hasPart <http://lblod.data.gift/vocabularies/vmm/actie/14633597> .
#   }
# }

# %%
for expression in all_uris['ap_expr'][1001:1200]:
    print(expression)
# Out:
# http://lblod.data.gift/vocabularies/vmm/actieplan/5398098/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5398099/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5398100/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5398108/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5398107/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5398110/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5398109/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5398112/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5398111/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5398113/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5398114/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5398101/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5398102/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5398104/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5398105/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5398106/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5398103/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5398097/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5385333/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5385331/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5385332/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5387201/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5387199/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5387200/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5384910/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5384911/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5384909/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5384916/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5384915/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5384918/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5384919/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5384922/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5384913/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5384914/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5384912/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5384917/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5384920/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5384921/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5382200/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5382198/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5382199/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5411998/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5411997/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5411996/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5411999/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5412000/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5411995/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5411994/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5412004/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5412005/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5412006/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5412001/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5412002/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5412003/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5412017/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5412018/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5412020/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5412019/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5412014/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5412015/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5412016/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5412021/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5412011/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5412013/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5412012/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5411991/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5411993/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5411992/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5412007/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5412008/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5412009/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5412010/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396191/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396188/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396190/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396189/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396187/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396195/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396194/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396196/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396200/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396218/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396219/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396220/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396221/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396229/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396231/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396230/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396232/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396241/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396240/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396239/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396172/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396174/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396173/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396175/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396186/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396199/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396203/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396202/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396201/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396223/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396226/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396224/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396225/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396222/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396255/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396254/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396228/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396227/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396245/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396244/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396246/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396242/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396243/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396181/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396177/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396180/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396176/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396178/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396179/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396247/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396183/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396185/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396184/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396182/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396192/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396193/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396197/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396198/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396205/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396209/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396207/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396204/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396206/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396208/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396214/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396215/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396212/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396210/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396211/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396213/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396217/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396216/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396234/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396233/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396235/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396236/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396237/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396238/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396249/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396248/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396250/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396251/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396253/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5396252/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5404991/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5404994/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5404992/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5404993/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5404996/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5405000/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5404998/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5404995/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5404999/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5404997/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5405003/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5405002/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5405007/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5405006/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5405004/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5405005/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5405001/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5405054/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5405048/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5405064/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5405050/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5405067/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5405066/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5405051/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5405052/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5405047/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5405061/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5405053/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5405065/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5405056/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5405057/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5405063/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5405058/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5405059/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5405062/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5405049/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5405055/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5405060/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5405074/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5405077/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5405078/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5405079/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5405070/expression

# %% [markdown]
# ## 5. Execute the inserts

# %%
# Virtuoso's SPARQL compiler runs out of memory at roughly 5,000
# triple statements in one INSERT DATA query. Stay comfortably below it.
MAX_TRIPLES_PER_UPDATE = 4_000

successful = 0
failed: list[tuple[int, str, str]] = []

for index, (line_number, delivery_id, triples) in enumerate(generated_updates, start=1):
    current_batch = 0
    try:
        batches = [
            triples[offset : offset + MAX_TRIPLES_PER_UPDATE]
            for offset in range(0, len(triples), MAX_TRIPLES_PER_UPDATE)
        ]

        if DRY_RUN:
            print(
                f"[DRY RUN] {index}/{len(generated_updates)} "
                f"delivery {delivery_id}: {len(triples)} triples "
                f"in {len(batches)} batch(es)"
            )
            continue

        for current_batch, batch in enumerate(batches, start=1):
            sparql_update(build_insert_query(batch))

        successful += 1
        print(
            f"Inserted {index}/{len(generated_updates)}: "
            f"delivery {delivery_id} ({len(triples)} triples in "
            f"{len(batches)} batch(es))"
        )
    except Exception as exc:
        batch_context = (
            f"batch {current_batch}/{len(batches)}: "
            if current_batch and 'batches' in locals()
            else ""
        )
        error = f"{batch_context}{exc}"
        failed.append((line_number, delivery_id, error))
        print(
            f"FAILED line {line_number}, delivery {delivery_id}: {error}"
        )

if DRY_RUN:
    print("Dry run complete; no updates were sent.")
else:
    print(f"\nSuccessfully inserted: {successful}")
    print(f"Failed: {len(failed)}")
    if failed:
        print("\nFailures:")
        for line_number, delivery_id, error in failed:
            print(f"  line {line_number}, delivery {delivery_id}: {error}")
# Out:
# Inserted 1/969: delivery 10000158105 (290 triples in 1 batch(es))
# Inserted 2/969: delivery 10000160197 (5570 triples in 2 batch(es))
# Inserted 3/969: delivery 10000160269 (57 triples in 1 batch(es))
# Inserted 4/969: delivery 10000160445 (5370 triples in 2 batch(es))
# Inserted 5/969: delivery 10000160659 (969 triples in 1 batch(es))
# Inserted 6/969: delivery 10000160883 (176 triples in 1 batch(es))
# Inserted 7/969: delivery 10000160906 (325 triples in 1 batch(es))
# Inserted 8/969: delivery 10000160915 (131 triples in 1 batch(es))
# Inserted 9/969: delivery 10000160919 (52 triples in 1 batch(es))
# Inserted 10/969: delivery 10000160920 (4693 triples in 2 batch(es))
# Inserted 11/969: delivery 10000160932 (1583 triples in 1 batch(es))
# Inserted 12/969: delivery 10000160938 (343 triples in 1 batch(es))
# Inserted 13/969: delivery 10000160940 (543 triples in 1 batch(es))
# Inserted 14/969: delivery 10000160945 (182 triples in 1 batch(es))
# Inserted 15/969: delivery 10000160946 (769 triples in 1 batch(es))
# Inserted 16/969: delivery 10000160948 (2735 triples in 1 batch(es))
# Inserted 17/969: delivery 10000160949 (3121 triples in 1 batch(es))
# Inserted 18/969: delivery 10000160951 (3291 triples in 1 batch(es))
# Inserted 19/969: delivery 10000160952 (1425 triples in 1 batch(es))
# Inserted 20/969: delivery 10000160954 (9074 triples in 3 batch(es))
# Inserted 21/969: delivery 10000160966 (1332 triples in 1 batch(es))
# Inserted 22/969: delivery 10000160967 (883 triples in 1 batch(es))
# Inserted 23/969: delivery 10000160968 (1199 triples in 1 batch(es))
# Inserted 24/969: delivery 10000160969 (1199 triples in 1 batch(es))
# Inserted 25/969: delivery 10000160970 (3865 triples in 1 batch(es))
# Inserted 26/969: delivery 10000160980 (213 triples in 1 batch(es))
# Inserted 27/969: delivery 10000160982 (262 triples in 1 batch(es))
# Inserted 28/969: delivery 10000160983 (80 triples in 1 batch(es))
# Inserted 29/969: delivery 10000160986 (2383 triples in 1 batch(es))
# Inserted 30/969: delivery 10000160987 (3843 triples in 1 batch(es))
# Inserted 31/969: delivery 10000160990 (203 triples in 1 batch(es))
# Inserted 32/969: delivery 10000160992 (1757 triples in 1 batch(es))
# Inserted 33/969: delivery 10000160995 (8826 triples in 3 batch(es))
# Inserted 34/969: delivery 10000160996 (875 triples in 1 batch(es))
# Inserted 35/969: delivery 10000160998 (1788 triples in 1 batch(es))
# Inserted 36/969: delivery 10000160999 (1345 triples in 1 batch(es))
# Inserted 37/969: delivery 10000161002 (2073 triples in 1 batch(es))
# Inserted 38/969: delivery 10000161004 (2736 triples in 1 batch(es))
# Inserted 39/969: delivery 10000161005 (1393 triples in 1 batch(es))
# Inserted 40/969: delivery 10000161008 (4147 triples in 2 batch(es))
# Inserted 41/969: delivery 10000161009 (127 triples in 1 batch(es))
# Inserted 42/969: delivery 10000161010 (2300 triples in 1 batch(es))
# Inserted 43/969: delivery 10000161011 (241 triples in 1 batch(es))
# Inserted 44/969: delivery 10000161012 (215 triples in 1 batch(es))
# Inserted 45/969: delivery 10000161013 (57 triples in 1 batch(es))
# Inserted 46/969: delivery 10000161018 (2847 triples in 1 batch(es))
# Inserted 47/969: delivery 10000161019 (2847 triples in 1 batch(es))
# Inserted 48/969: delivery 10000161024 (1383 triples in 1 batch(es))
# Inserted 49/969: delivery 10000161030 (2258 triples in 1 batch(es))
# Inserted 50/969: delivery 10000161031 (3700 triples in 1 batch(es))
# Inserted 51/969: delivery 10000161032 (2260 triples in 1 batch(es))
# Inserted 52/969: delivery 10000161039 (1757 triples in 1 batch(es))
# Inserted 53/969: delivery 10000161043 (1201 triples in 1 batch(es))
# Inserted 54/969: delivery 10000161047 (177 triples in 1 batch(es))
# Inserted 55/969: delivery 10000161048 (6914 triples in 2 batch(es))
# Inserted 56/969: delivery 10000161050 (424 triples in 1 batch(es))
# Inserted 57/969: delivery 10000161051 (4832 triples in 2 batch(es))
# Inserted 58/969: delivery 10000161052 (1241 triples in 1 batch(es))
# Inserted 59/969: delivery 10000161053 (2282 triples in 1 batch(es))
# Inserted 60/969: delivery 10000161054 (2914 triples in 1 batch(es))
# Inserted 61/969: delivery 10000161056 (181 triples in 1 batch(es))
# Inserted 62/969: delivery 10000161058 (8328 triples in 3 batch(es))
# Inserted 63/969: delivery 10000161059 (95 triples in 1 batch(es))
# Inserted 64/969: delivery 10000161060 (1967 triples in 1 batch(es))
# Inserted 65/969: delivery 10000161061 (3826 triples in 1 batch(es))
# Inserted 66/969: delivery 10000161063 (95 triples in 1 batch(es))
# Inserted 67/969: delivery 10000161064 (1278 triples in 1 batch(es))
# Inserted 68/969: delivery 10000161065 (1400 triples in 1 batch(es))
# Inserted 69/969: delivery 10000161066 (1643 triples in 1 batch(es))
# Inserted 70/969: delivery 10000161068 (914 triples in 1 batch(es))
# Inserted 71/969: delivery 10000161072 (147 triples in 1 batch(es))
# Inserted 72/969: delivery 10000161073 (85 triples in 1 batch(es))
# Inserted 73/969: delivery 10000161076 (145 triples in 1 batch(es))
# Inserted 74/969: delivery 10000161077 (69 triples in 1 batch(es))
# Inserted 75/969: delivery 10000161079 (95 triples in 1 batch(es))
# Inserted 76/969: delivery 10000161080 (95 triples in 1 batch(es))
# Inserted 77/969: delivery 10000161081 (109 triples in 1 batch(es))
# Inserted 78/969: delivery 10000161082 (95 triples in 1 batch(es))
# Inserted 79/969: delivery 10000161083 (153 triples in 1 batch(es))
# Inserted 80/969: delivery 10000161086 (1691 triples in 1 batch(es))
# Inserted 81/969: delivery 10000161087 (1691 triples in 1 batch(es))
# Inserted 82/969: delivery 10000161089 (82 triples in 1 batch(es))
# Inserted 83/969: delivery 10000161090 (53 triples in 1 batch(es))
# Inserted 84/969: delivery 10000161092 (446 triples in 1 batch(es))
# Inserted 85/969: delivery 10000161095 (108 triples in 1 batch(es))
# Inserted 86/969: delivery 10000161097 (1829 triples in 1 batch(es))
# Inserted 87/969: delivery 10000161098 (2376 triples in 1 batch(es))
# Inserted 88/969: delivery 10000161099 (160 triples in 1 batch(es))
# Inserted 89/969: delivery 10000161100 (1493 triples in 1 batch(es))
# Inserted 90/969: delivery 10000161102 (2095 triples in 1 batch(es))
# Inserted 91/969: delivery 10000161103 (2095 triples in 1 batch(es))
# Inserted 92/969: delivery 10000161105 (2383 triples in 1 batch(es))
# Inserted 93/969: delivery 10000161107 (1358 triples in 1 batch(es))
# Inserted 94/969: delivery 10000161108 (82 triples in 1 batch(es))
# Inserted 95/969: delivery 10000161109 (171 triples in 1 batch(es))
# Inserted 96/969: delivery 10000161113 (589 triples in 1 batch(es))
# Inserted 97/969: delivery 10000161115 (732 triples in 1 batch(es))
# Inserted 98/969: delivery 10000161118 (4101 triples in 2 batch(es))
# Inserted 99/969: delivery 10000161120 (1339 triples in 1 batch(es))
# Inserted 100/969: delivery 10000161123 (1056 triples in 1 batch(es))
# Inserted 101/969: delivery 10000161124 (1276 triples in 1 batch(es))
# Inserted 102/969: delivery 10000161125 (2270 triples in 1 batch(es))
# Inserted 103/969: delivery 10000161126 (2270 triples in 1 batch(es))
# Inserted 104/969: delivery 10000161127 (871 triples in 1 batch(es))
# Inserted 105/969: delivery 10000161128 (3305 triples in 1 batch(es))
# Inserted 106/969: delivery 10000161130 (445 triples in 1 batch(es))
# Inserted 107/969: delivery 10000161131 (536 triples in 1 batch(es))
# Inserted 108/969: delivery 10000161132 (549 triples in 1 batch(es))
# Inserted 109/969: delivery 10000161133 (432 triples in 1 batch(es))
# Inserted 110/969: delivery 10000161134 (354 triples in 1 batch(es))
# Inserted 111/969: delivery 10000161135 (627 triples in 1 batch(es))
# Inserted 112/969: delivery 10000161136 (757 triples in 1 batch(es))
# Inserted 113/969: delivery 10000161137 (315 triples in 1 batch(es))
# Inserted 114/969: delivery 10000161139 (510 triples in 1 batch(es))
# Inserted 115/969: delivery 10000161140 (354 triples in 1 batch(es))
# Inserted 116/969: delivery 10000161141 (3111 triples in 1 batch(es))
# Inserted 117/969: delivery 10000161142 (471 triples in 1 batch(es))
# Inserted 118/969: delivery 10000161143 (3723 triples in 1 batch(es))
# Inserted 119/969: delivery 10000161144 (1057 triples in 1 batch(es))
# Inserted 120/969: delivery 10000161147 (143 triples in 1 batch(es))
# Inserted 121/969: delivery 10000161148 (1057 triples in 1 batch(es))
# Inserted 122/969: delivery 10000161149 (2160 triples in 1 batch(es))
# Inserted 123/969: delivery 10000161151 (1983 triples in 1 batch(es))
# Inserted 124/969: delivery 10000161152 (2152 triples in 1 batch(es))
# Inserted 125/969: delivery 10000161153 (231 triples in 1 batch(es))
# Inserted 126/969: delivery 10000161154 (1068 triples in 1 batch(es))
# Inserted 127/969: delivery 10000161155 (1679 triples in 1 batch(es))
# Inserted 128/969: delivery 10000161156 (1679 triples in 1 batch(es))
# Inserted 129/969: delivery 10000161157 (7492 triples in 2 batch(es))
# Inserted 130/969: delivery 10000161160 (1973 triples in 1 batch(es))
# Inserted 131/969: delivery 10000161161 (510 triples in 1 batch(es))
# Inserted 132/969: delivery 10000161162 (848 triples in 1 batch(es))
# Inserted 133/969: delivery 10000161163 (5891 triples in 2 batch(es))
# Inserted 134/969: delivery 10000161164 (3007 triples in 1 batch(es))
# Inserted 135/969: delivery 10000161166 (1722 triples in 1 batch(es))
# Inserted 136/969: delivery 10000161168 (55 triples in 1 batch(es))
# Inserted 137/969: delivery 10000161169 (5904 triples in 2 batch(es))
# Inserted 138/969: delivery 10000161172 (368 triples in 1 batch(es))
# Inserted 139/969: delivery 10000161173 (3813 triples in 1 batch(es))
# Inserted 140/969: delivery 10000161176 (1443 triples in 1 batch(es))
# Inserted 141/969: delivery 10000161178 (2188 triples in 1 batch(es))
# Inserted 142/969: delivery 10000161181 (3676 triples in 1 batch(es))
# Inserted 143/969: delivery 10000161182 (3537 triples in 1 batch(es))
# Inserted 144/969: delivery 10000161183 (435 triples in 1 batch(es))
# Inserted 145/969: delivery 10000161184 (875 triples in 1 batch(es))
# Inserted 146/969: delivery 10000161185 (1302 triples in 1 batch(es))
# Inserted 147/969: delivery 10000161186 (1990 triples in 1 batch(es))
# Inserted 148/969: delivery 10000161187 (834 triples in 1 batch(es))
# Inserted 149/969: delivery 10000161188 (3534 triples in 1 batch(es))
# Inserted 150/969: delivery 10000161189 (3534 triples in 1 batch(es))
# Inserted 151/969: delivery 10000161190 (1892 triples in 1 batch(es))
# Inserted 152/969: delivery 10000161192 (1770 triples in 1 batch(es))
# Inserted 153/969: delivery 10000161194 (433 triples in 1 batch(es))
# Inserted 154/969: delivery 10000161197 (2903 triples in 1 batch(es))
# Inserted 155/969: delivery 10000161198 (3095 triples in 1 batch(es))
# Inserted 156/969: delivery 10000161201 (1538 triples in 1 batch(es))
# Inserted 157/969: delivery 10000161202 (369 triples in 1 batch(es))
# Inserted 158/969: delivery 10000161204 (4389 triples in 2 batch(es))
# Inserted 159/969: delivery 10000161206 (1852 triples in 1 batch(es))
# Inserted 160/969: delivery 10000161208 (1852 triples in 1 batch(es))
# Inserted 161/969: delivery 10000161209 (1383 triples in 1 batch(es))
# Inserted 162/969: delivery 10000161212 (5165 triples in 2 batch(es))
# Inserted 163/969: delivery 10000161213 (4203 triples in 2 batch(es))
# Inserted 164/969: delivery 10000161214 (1954 triples in 1 batch(es))
# Inserted 165/969: delivery 10000161217 (1531 triples in 1 batch(es))
# Inserted 166/969: delivery 10000161219 (326 triples in 1 batch(es))
# Inserted 167/969: delivery 10000161220 (4203 triples in 2 batch(es))
# Inserted 168/969: delivery 10000161221 (4203 triples in 2 batch(es))
# Inserted 169/969: delivery 10000161223 (2032 triples in 1 batch(es))
# Inserted 170/969: delivery 10000161224 (869 triples in 1 batch(es))
# Inserted 171/969: delivery 10000161226 (493 triples in 1 batch(es))
# Inserted 172/969: delivery 10000161227 (3803 triples in 1 batch(es))
# Inserted 173/969: delivery 10000161228 (3727 triples in 1 batch(es))
# Inserted 174/969: delivery 10000161229 (3087 triples in 1 batch(es))
# Inserted 175/969: delivery 10000161232 (3087 triples in 1 batch(es))
# Inserted 176/969: delivery 10000161233 (1968 triples in 1 batch(es))
# Inserted 177/969: delivery 10000161234 (1931 triples in 1 batch(es))
# Inserted 178/969: delivery 10000161235 (1499 triples in 1 batch(es))
# Inserted 179/969: delivery 10000161237 (524 triples in 1 batch(es))
# Inserted 180/969: delivery 10000161241 (2370 triples in 1 batch(es))
# Inserted 181/969: delivery 10000161242 (2292 triples in 1 batch(es))
# Inserted 182/969: delivery 10000161243 (2641 triples in 1 batch(es))
# Inserted 183/969: delivery 10000161244 (841 triples in 1 batch(es))
# Inserted 184/969: delivery 10000161247 (1343 triples in 1 batch(es))
# Inserted 185/969: delivery 10000161248 (251 triples in 1 batch(es))
# Inserted 186/969: delivery 10000161249 (4749 triples in 2 batch(es))
# Inserted 187/969: delivery 10000161250 (2329 triples in 1 batch(es))
# Inserted 188/969: delivery 10000161252 (2914 triples in 1 batch(es))
# Inserted 189/969: delivery 10000161253 (795 triples in 1 batch(es))
# Inserted 190/969: delivery 10000161254 (451 triples in 1 batch(es))
# Inserted 191/969: delivery 10000161255 (121 triples in 1 batch(es))
# Inserted 192/969: delivery 10000161256 (56 triples in 1 batch(es))
# Inserted 193/969: delivery 10000161257 (4242 triples in 2 batch(es))
# Inserted 194/969: delivery 10000161258 (1358 triples in 1 batch(es))
# Inserted 195/969: delivery 10000161260 (1182 triples in 1 batch(es))
# Inserted 196/969: delivery 10000161261 (2472 triples in 1 batch(es))
# Inserted 197/969: delivery 10000161262 (94 triples in 1 batch(es))
# Inserted 198/969: delivery 10000161263 (1723 triples in 1 batch(es))
# Inserted 199/969: delivery 10000161264 (3947 triples in 1 batch(es))
# Inserted 200/969: delivery 10000161265 (4737 triples in 2 batch(es))
# Inserted 201/969: delivery 10000161266 (537 triples in 1 batch(es))
# Inserted 202/969: delivery 10000161267 (1239 triples in 1 batch(es))
# Inserted 203/969: delivery 10000161269 (1187 triples in 1 batch(es))
# Inserted 204/969: delivery 10000161270 (3150 triples in 1 batch(es))
# Inserted 205/969: delivery 10000161271 (7608 triples in 2 batch(es))
# Inserted 206/969: delivery 10000161272 (3306 triples in 1 batch(es))
# Inserted 207/969: delivery 10000161274 (2238 triples in 1 batch(es))
# Inserted 208/969: delivery 10000161275 (1343 triples in 1 batch(es))
# Inserted 209/969: delivery 10000161277 (2835 triples in 1 batch(es))
# Inserted 210/969: delivery 10000161278 (886 triples in 1 batch(es))
# Inserted 211/969: delivery 10000161279 (4106 triples in 2 batch(es))
# Inserted 212/969: delivery 10000161280 (241 triples in 1 batch(es))
# Inserted 213/969: delivery 10000161282 (3392 triples in 1 batch(es))
# Inserted 214/969: delivery 10000161283 (1707 triples in 1 batch(es))
# Inserted 215/969: delivery 10000161284 (2534 triples in 1 batch(es))
# Inserted 216/969: delivery 10000161285 (5761 triples in 2 batch(es))
# Inserted 217/969: delivery 10000161287 (2803 triples in 1 batch(es))
# Inserted 218/969: delivery 10000161289 (2801 triples in 1 batch(es))
# Inserted 219/969: delivery 10000161293 (732 triples in 1 batch(es))
# Inserted 220/969: delivery 10000161294 (658 triples in 1 batch(es))
# Inserted 221/969: delivery 10000161295 (3375 triples in 1 batch(es))
# Inserted 222/969: delivery 10000161296 (56 triples in 1 batch(es))
# Inserted 223/969: delivery 10000161299 (2221 triples in 1 batch(es))
# Inserted 224/969: delivery 10000161301 (1003 triples in 1 batch(es))
# Inserted 225/969: delivery 10000161302 (1921 triples in 1 batch(es))
# Inserted 226/969: delivery 10000161303 (576 triples in 1 batch(es))
# Inserted 227/969: delivery 10000161304 (290 triples in 1 batch(es))
# Inserted 228/969: delivery 10000161305 (485 triples in 1 batch(es))
# Inserted 229/969: delivery 10000161306 (56 triples in 1 batch(es))
# Inserted 230/969: delivery 10000161307 (5003 triples in 2 batch(es))
# Inserted 231/969: delivery 10000161308 (3787 triples in 1 batch(es))
# Inserted 232/969: delivery 10000161309 (69 triples in 1 batch(es))
# Inserted 233/969: delivery 10000161310 (524 triples in 1 batch(es))
# Inserted 234/969: delivery 10000161311 (1031 triples in 1 batch(es))
# Inserted 235/969: delivery 10000161313 (2283 triples in 1 batch(es))
# Inserted 236/969: delivery 10000161314 (2695 triples in 1 batch(es))
# Inserted 237/969: delivery 10000161315 (2964 triples in 1 batch(es))
# Inserted 238/969: delivery 10000161316 (587 triples in 1 batch(es))
# Inserted 239/969: delivery 10000161317 (1920 triples in 1 batch(es))
# Inserted 240/969: delivery 10000161320 (222 triples in 1 batch(es))
# Inserted 241/969: delivery 10000161322 (3455 triples in 1 batch(es))
# Inserted 242/969: delivery 10000161323 (434 triples in 1 batch(es))
# Inserted 243/969: delivery 10000161324 (16899 triples in 5 batch(es))
# Inserted 244/969: delivery 10000161326 (2410 triples in 1 batch(es))
# Inserted 245/969: delivery 10000161327 (3226 triples in 1 batch(es))
# Inserted 246/969: delivery 10000161328 (3226 triples in 1 batch(es))
# Inserted 247/969: delivery 10000161329 (3512 triples in 1 batch(es))
# Inserted 248/969: delivery 10000161330 (3512 triples in 1 batch(es))
# Inserted 249/969: delivery 10000161331 (160 triples in 1 batch(es))
# Inserted 250/969: delivery 10000161332 (1018 triples in 1 batch(es))
# Inserted 251/969: delivery 10000161333 (1198 triples in 1 batch(es))
# Inserted 252/969: delivery 10000161334 (1239 triples in 1 batch(es))
# Inserted 253/969: delivery 10000161336 (57 triples in 1 batch(es))
# Inserted 254/969: delivery 10000161340 (4113 triples in 2 batch(es))
# Inserted 255/969: delivery 10000161341 (213 triples in 1 batch(es))
# Inserted 256/969: delivery 10000161342 (215 triples in 1 batch(es))
# Inserted 257/969: delivery 10000161343 (209 triples in 1 batch(es))
# Inserted 258/969: delivery 10000161344 (1210 triples in 1 batch(es))
# Inserted 259/969: delivery 10000161345 (7789 triples in 2 batch(es))
# Inserted 260/969: delivery 10000161346 (4693 triples in 2 batch(es))
# Inserted 261/969: delivery 10000161347 (11366 triples in 3 batch(es))
# Inserted 262/969: delivery 10000161348 (965 triples in 1 batch(es))
# Inserted 263/969: delivery 10000161350 (1707 triples in 1 batch(es))
# Inserted 264/969: delivery 10000161351 (10729 triples in 3 batch(es))
# Inserted 265/969: delivery 10000161352 (1090 triples in 1 batch(es))
# Inserted 266/969: delivery 10000161355 (901 triples in 1 batch(es))
# Inserted 267/969: delivery 10000161356 (1434 triples in 1 batch(es))
# Inserted 268/969: delivery 10000161358 (2232 triples in 1 batch(es))
# Inserted 269/969: delivery 10000161361 (1107 triples in 1 batch(es))
# Inserted 270/969: delivery 10000161362 (1504 triples in 1 batch(es))
# Inserted 271/969: delivery 10000161363 (1408 triples in 1 batch(es))
# Inserted 272/969: delivery 10000161365 (1603 triples in 1 batch(es))
# Inserted 273/969: delivery 10000161367 (6558 triples in 2 batch(es))
# Inserted 274/969: delivery 10000161368 (5012 triples in 2 batch(es))
# Inserted 275/969: delivery 10000161369 (603 triples in 1 batch(es))
# Inserted 276/969: delivery 10000161370 (5012 triples in 2 batch(es))
# Inserted 277/969: delivery 10000161371 (1410 triples in 1 batch(es))
# Inserted 278/969: delivery 10000161372 (1291 triples in 1 batch(es))
# Inserted 279/969: delivery 10000161373 (1068 triples in 1 batch(es))
# Inserted 280/969: delivery 10000161374 (2279 triples in 1 batch(es))
# Inserted 281/969: delivery 10000161375 (2279 triples in 1 batch(es))
# Inserted 282/969: delivery 10000161376 (6227 triples in 2 batch(es))
# Inserted 283/969: delivery 10000161377 (756 triples in 1 batch(es))
# Inserted 284/969: delivery 10000161379 (1354 triples in 1 batch(es))
# Inserted 285/969: delivery 10000161380 (1516 triples in 1 batch(es))
# Inserted 286/969: delivery 10000161381 (1523 triples in 1 batch(es))
# Inserted 287/969: delivery 10000161383 (1278 triples in 1 batch(es))
# Inserted 288/969: delivery 10000161384 (1986 triples in 1 batch(es))
# Inserted 289/969: delivery 10000161385 (2296 triples in 1 batch(es))
# Inserted 290/969: delivery 10000161386 (4004 triples in 2 batch(es))
# Inserted 291/969: delivery 10000161387 (597 triples in 1 batch(es))
# Inserted 292/969: delivery 10000161388 (2607 triples in 1 batch(es))
# Inserted 293/969: delivery 10000161389 (756 triples in 1 batch(es))
# Inserted 294/969: delivery 10000161390 (93 triples in 1 batch(es))
# Inserted 295/969: delivery 10000161392 (238 triples in 1 batch(es))
# Inserted 296/969: delivery 10000161393 (5524 triples in 2 batch(es))
# Inserted 297/969: delivery 10000161394 (5524 triples in 2 batch(es))
# Inserted 298/969: delivery 10000161395 (1298 triples in 1 batch(es))
# Inserted 299/969: delivery 10000161398 (430 triples in 1 batch(es))
# Inserted 300/969: delivery 10000161400 (2372 triples in 1 batch(es))
# Inserted 301/969: delivery 10000161403 (1412 triples in 1 batch(es))
# Inserted 302/969: delivery 10000161404 (1935 triples in 1 batch(es))
# Inserted 303/969: delivery 10000161405 (2692 triples in 1 batch(es))
# Inserted 304/969: delivery 10000161406 (2855 triples in 1 batch(es))
# Inserted 305/969: delivery 10000161407 (1583 triples in 1 batch(es))
# Inserted 306/969: delivery 10000161408 (2855 triples in 1 batch(es))
# Inserted 307/969: delivery 10000161409 (2097 triples in 1 batch(es))
# Inserted 308/969: delivery 10000161411 (2598 triples in 1 batch(es))
# Inserted 309/969: delivery 10000161412 (4597 triples in 2 batch(es))
# Inserted 310/969: delivery 10000161413 (2592 triples in 1 batch(es))
# Inserted 311/969: delivery 10000161414 (2058 triples in 1 batch(es))
# Inserted 312/969: delivery 10000161415 (123 triples in 1 batch(es))
# Inserted 313/969: delivery 10000161417 (496 triples in 1 batch(es))
# Inserted 314/969: delivery 10000161418 (5728 triples in 2 batch(es))
# Inserted 315/969: delivery 10000161420 (2287 triples in 1 batch(es))
# Inserted 316/969: delivery 10000161422 (1085 triples in 1 batch(es))
# Inserted 317/969: delivery 10000161424 (202 triples in 1 batch(es))
# Inserted 318/969: delivery 10000161427 (16948 triples in 5 batch(es))
# Inserted 319/969: delivery 10000161428 (4030 triples in 2 batch(es))
# Inserted 320/969: delivery 10000161429 (105 triples in 1 batch(es))
# Inserted 321/969: delivery 10000161431 (1524 triples in 1 batch(es))
# Inserted 322/969: delivery 10000161434 (4881 triples in 2 batch(es))
# Inserted 323/969: delivery 10000161436 (4881 triples in 2 batch(es))
# Inserted 324/969: delivery 10000161437 (1848 triples in 1 batch(es))
# Inserted 325/969: delivery 10000161439 (104 triples in 1 batch(es))
# Inserted 326/969: delivery 10000161440 (1935 triples in 1 batch(es))
# Inserted 327/969: delivery 10000161441 (2124 triples in 1 batch(es))
# Inserted 328/969: delivery 10000161443 (3984 triples in 1 batch(es))
# Inserted 329/969: delivery 10000161445 (2418 triples in 1 batch(es))
# Inserted 330/969: delivery 10000161447 (2418 triples in 1 batch(es))
# Inserted 331/969: delivery 10000161448 (9611 triples in 3 batch(es))
# Inserted 332/969: delivery 10000161450 (1778 triples in 1 batch(es))
# Inserted 333/969: delivery 10000161451 (796 triples in 1 batch(es))
# Inserted 334/969: delivery 10000161452 (3059 triples in 1 batch(es))
# Inserted 335/969: delivery 10000161453 (485 triples in 1 batch(es))
# Inserted 336/969: delivery 10000161454 (1851 triples in 1 batch(es))
# Inserted 337/969: delivery 10000161457 (202 triples in 1 batch(es))
# Inserted 338/969: delivery 10000161458 (5011 triples in 2 batch(es))
# Inserted 339/969: delivery 10000161460 (5011 triples in 2 batch(es))
# Inserted 340/969: delivery 10000161461 (4383 triples in 2 batch(es))
# Inserted 341/969: delivery 10000161462 (1227 triples in 1 batch(es))
# Inserted 342/969: delivery 10000161465 (323 triples in 1 batch(es))
# Inserted 343/969: delivery 10000161466 (704 triples in 1 batch(es))
# Inserted 344/969: delivery 10000161467 (1397 triples in 1 batch(es))
# Inserted 345/969: delivery 10000161469 (1397 triples in 1 batch(es))
# Inserted 346/969: delivery 10000161470 (1640 triples in 1 batch(es))
# Inserted 347/969: delivery 10000161471 (1457 triples in 1 batch(es))
# Inserted 348/969: delivery 10000161473 (161 triples in 1 batch(es))
# Inserted 349/969: delivery 10000161476 (2486 triples in 1 batch(es))
# Inserted 350/969: delivery 10000161477 (1422 triples in 1 batch(es))
# Inserted 351/969: delivery 10000161479 (2992 triples in 1 batch(es))
# Inserted 352/969: delivery 10000161481 (2656 triples in 1 batch(es))
# Inserted 353/969: delivery 10000161483 (2338 triples in 1 batch(es))
# Inserted 354/969: delivery 10000161485 (4396 triples in 2 batch(es))
# Inserted 355/969: delivery 10000161486 (394 triples in 1 batch(es))
# Inserted 356/969: delivery 10000161487 (1174 triples in 1 batch(es))
# Inserted 357/969: delivery 10000161488 (1466 triples in 1 batch(es))
# Inserted 358/969: delivery 10000161489 (111 triples in 1 batch(es))
# Inserted 359/969: delivery 10000161490 (836 triples in 1 batch(es))
# Inserted 360/969: delivery 10000161492 (2721 triples in 1 batch(es))
# Inserted 361/969: delivery 10000161494 (2721 triples in 1 batch(es))
# Inserted 362/969: delivery 10000161495 (2721 triples in 1 batch(es))
# Inserted 363/969: delivery 10000161496 (2721 triples in 1 batch(es))
# Inserted 364/969: delivery 10000161499 (899 triples in 1 batch(es))
# Inserted 365/969: delivery 10000161500 (3081 triples in 1 batch(es))
# Inserted 366/969: delivery 10000161501 (899 triples in 1 batch(es))
# Inserted 367/969: delivery 10000161502 (5175 triples in 2 batch(es))
# Inserted 368/969: delivery 10000161503 (2206 triples in 1 batch(es))
# Inserted 369/969: delivery 10000161504 (1239 triples in 1 batch(es))
# Inserted 370/969: delivery 10000161506 (2747 triples in 1 batch(es))
# Inserted 371/969: delivery 10000161507 (1239 triples in 1 batch(es))
# Inserted 372/969: delivery 10000161508 (1239 triples in 1 batch(es))
# Inserted 373/969: delivery 10000161510 (90 triples in 1 batch(es))
# Inserted 374/969: delivery 10000161514 (742 triples in 1 batch(es))
# Inserted 375/969: delivery 10000161515 (117 triples in 1 batch(es))
# Inserted 376/969: delivery 10000161516 (262 triples in 1 batch(es))
# Inserted 377/969: delivery 10000161517 (54 triples in 1 batch(es))
# Inserted 378/969: delivery 10000161518 (3955 triples in 1 batch(es))
# Inserted 379/969: delivery 10000161520 (4216 triples in 2 batch(es))
# Inserted 380/969: delivery 10000161521 (1095 triples in 1 batch(es))
# Inserted 381/969: delivery 10000161522 (4216 triples in 2 batch(es))
# Inserted 382/969: delivery 10000161523 (791 triples in 1 batch(es))
# Inserted 383/969: delivery 10000161525 (1478 triples in 1 batch(es))
# Inserted 384/969: delivery 10000161527 (1524 triples in 1 batch(es))
# Inserted 385/969: delivery 10000161528 (6524 triples in 2 batch(es))
# Inserted 386/969: delivery 10000161529 (1396 triples in 1 batch(es))
# Inserted 387/969: delivery 10000161530 (6512 triples in 2 batch(es))
# Inserted 388/969: delivery 10000161531 (2153 triples in 1 batch(es))
# Inserted 389/969: delivery 10000161532 (2487 triples in 1 batch(es))
# Inserted 390/969: delivery 10000161533 (1953 triples in 1 batch(es))
# Inserted 391/969: delivery 10000161535 (1427 triples in 1 batch(es))
# Inserted 392/969: delivery 10000161536 (700 triples in 1 batch(es))
# Inserted 393/969: delivery 10000161537 (3039 triples in 1 batch(es))
# Inserted 394/969: delivery 10000161538 (3039 triples in 1 batch(es))
# Inserted 395/969: delivery 10000161539 (700 triples in 1 batch(es))
# Inserted 396/969: delivery 10000161541 (239 triples in 1 batch(es))
# Inserted 397/969: delivery 10000161542 (196 triples in 1 batch(es))
# Inserted 398/969: delivery 10000161544 (1213 triples in 1 batch(es))
# Inserted 399/969: delivery 10000161546 (958 triples in 1 batch(es))
# Inserted 400/969: delivery 10000161547 (1565 triples in 1 batch(es))
# Inserted 401/969: delivery 10000161548 (1484 triples in 1 batch(es))
# Inserted 402/969: delivery 10000161551 (1849 triples in 1 batch(es))
# Inserted 403/969: delivery 10000161552 (2379 triples in 1 batch(es))
# Inserted 404/969: delivery 10000161553 (3087 triples in 1 batch(es))
# Inserted 405/969: delivery 10000161554 (123 triples in 1 batch(es))
# Inserted 406/969: delivery 10000161555 (2171 triples in 1 batch(es))
# Inserted 407/969: delivery 10000161556 (3617 triples in 1 batch(es))
# Inserted 408/969: delivery 10000161558 (66 triples in 1 batch(es))
# Inserted 409/969: delivery 10000161561 (2916 triples in 1 batch(es))
# Inserted 410/969: delivery 10000161562 (545 triples in 1 batch(es))
# Inserted 411/969: delivery 10000161563 (392 triples in 1 batch(es))
# Inserted 412/969: delivery 10000161564 (3282 triples in 1 batch(es))
# Inserted 413/969: delivery 10000161565 (1070 triples in 1 batch(es))
# Inserted 414/969: delivery 10000161566 (2081 triples in 1 batch(es))
# Inserted 415/969: delivery 10000161567 (820 triples in 1 batch(es))
# Inserted 416/969: delivery 10000161568 (2838 triples in 1 batch(es))
# Inserted 417/969: delivery 10000161569 (1148 triples in 1 batch(es))
# Inserted 418/969: delivery 10000161570 (1062 triples in 1 batch(es))
# Inserted 419/969: delivery 10000161573 (344 triples in 1 batch(es))
# Inserted 420/969: delivery 10000161574 (1513 triples in 1 batch(es))
# Inserted 421/969: delivery 10000161576 (4 triples in 1 batch(es))
# Inserted 422/969: delivery 10000161577 (1707 triples in 1 batch(es))
# Inserted 423/969: delivery 10000161578 (1757 triples in 1 batch(es))
# Inserted 424/969: delivery 10000161579 (1757 triples in 1 batch(es))
# Inserted 425/969: delivery 10000161580 (2123 triples in 1 batch(es))
# Inserted 426/969: delivery 10000161581 (2874 triples in 1 batch(es))
# Inserted 427/969: delivery 10000161583 (847 triples in 1 batch(es))
# Inserted 428/969: delivery 10000161585 (1068 triples in 1 batch(es))
# Inserted 429/969: delivery 10000161586 (1514 triples in 1 batch(es))
# Inserted 430/969: delivery 10000161587 (1514 triples in 1 batch(es))
# Inserted 431/969: delivery 10000161589 (2871 triples in 1 batch(es))
# Inserted 432/969: delivery 10000161590 (1802 triples in 1 batch(es))
# Inserted 433/969: delivery 10000161592 (1284 triples in 1 batch(es))
# Inserted 434/969: delivery 10000161593 (1284 triples in 1 batch(es))
# Inserted 435/969: delivery 10000161594 (1176 triples in 1 batch(es))
# Inserted 436/969: delivery 10000161595 (823 triples in 1 batch(es))
# Inserted 437/969: delivery 10000161600 (223 triples in 1 batch(es))
# Inserted 438/969: delivery 10000161612 (56 triples in 1 batch(es))
# Inserted 439/969: delivery 10000161613 (3566 triples in 1 batch(es))
# Inserted 440/969: delivery 10000161615 (1828 triples in 1 batch(es))
# Inserted 441/969: delivery 10000161616 (277 triples in 1 batch(es))
# Inserted 442/969: delivery 10000161617 (2773 triples in 1 batch(es))
# Inserted 443/969: delivery 10000161618 (1963 triples in 1 batch(es))
# Inserted 444/969: delivery 10000161619 (854 triples in 1 batch(es))
# Inserted 445/969: delivery 10000161620 (82 triples in 1 batch(es))
# Inserted 446/969: delivery 10000161621 (2851 triples in 1 batch(es))
# Inserted 447/969: delivery 10000161622 (415 triples in 1 batch(es))
# Inserted 448/969: delivery 10000161623 (483 triples in 1 batch(es))
# Inserted 449/969: delivery 10000161624 (3307 triples in 1 batch(es))
# Inserted 450/969: delivery 10000161625 (3306 triples in 1 batch(es))
# Inserted 451/969: delivery 10000161626 (1590 triples in 1 batch(es))
# Inserted 452/969: delivery 10000161627 (2215 triples in 1 batch(es))
# Inserted 453/969: delivery 10000161628 (1124 triples in 1 batch(es))
# Inserted 454/969: delivery 10000161629 (4 triples in 1 batch(es))
# Inserted 455/969: delivery 10000161630 (638 triples in 1 batch(es))
# Inserted 456/969: delivery 10000161632 (757 triples in 1 batch(es))
# Inserted 457/969: delivery 10000161634 (771 triples in 1 batch(es))
# Inserted 458/969: delivery 10000161635 (782 triples in 1 batch(es))
# Inserted 459/969: delivery 10000161637 (1153 triples in 1 batch(es))
# Inserted 460/969: delivery 10000161638 (912 triples in 1 batch(es))
# Inserted 461/969: delivery 10000161639 (169 triples in 1 batch(es))
# Inserted 462/969: delivery 10000161640 (85 triples in 1 batch(es))
# Inserted 463/969: delivery 10000161641 (3011 triples in 1 batch(es))
# Inserted 464/969: delivery 10000161643 (1723 triples in 1 batch(es))
# Inserted 465/969: delivery 10000161645 (615 triples in 1 batch(es))
# Inserted 466/969: delivery 10000161647 (2029 triples in 1 batch(es))
# Inserted 467/969: delivery 10000161648 (1079 triples in 1 batch(es))
# Inserted 468/969: delivery 10000161649 (485 triples in 1 batch(es))
# Inserted 469/969: delivery 10000161651 (670 triples in 1 batch(es))
# Inserted 470/969: delivery 10000161652 (305 triples in 1 batch(es))
# Inserted 471/969: delivery 10000161653 (2210 triples in 1 batch(es))
# Inserted 472/969: delivery 10000161654 (3055 triples in 1 batch(es))
# Inserted 473/969: delivery 10000161655 (3031 triples in 1 batch(es))
# Inserted 474/969: delivery 10000161656 (1263 triples in 1 batch(es))
# Inserted 475/969: delivery 10000161657 (646 triples in 1 batch(es))
# Inserted 476/969: delivery 10000161658 (1859 triples in 1 batch(es))
# Inserted 477/969: delivery 10000161659 (1024 triples in 1 batch(es))
# Inserted 478/969: delivery 10000161661 (57 triples in 1 batch(es))
# Inserted 479/969: delivery 10000161662 (281 triples in 1 batch(es))
# Inserted 480/969: delivery 10000161663 (295 triples in 1 batch(es))
# Inserted 481/969: delivery 10000161664 (463 triples in 1 batch(es))
# Inserted 482/969: delivery 10000161665 (533 triples in 1 batch(es))
# Inserted 483/969: delivery 10000161666 (407 triples in 1 batch(es))
# Inserted 484/969: delivery 10000161667 (337 triples in 1 batch(es))
# Inserted 485/969: delivery 10000161668 (211 triples in 1 batch(es))
# Inserted 486/969: delivery 10000161669 (281 triples in 1 batch(es))
# Inserted 487/969: delivery 10000161670 (225 triples in 1 batch(es))
# Inserted 488/969: delivery 10000161671 (365 triples in 1 batch(es))
# Inserted 489/969: delivery 10000161672 (415 triples in 1 batch(es))
# Inserted 490/969: delivery 10000161675 (942 triples in 1 batch(es))
# Inserted 491/969: delivery 10000161678 (966 triples in 1 batch(es))
# Inserted 492/969: delivery 10000161679 (132 triples in 1 batch(es))
# Inserted 493/969: delivery 10000161680 (2111 triples in 1 batch(es))
# Inserted 494/969: delivery 10000161685 (1710 triples in 1 batch(es))
# Inserted 495/969: delivery 10000161689 (2802 triples in 1 batch(es))
# Inserted 496/969: delivery 10000161690 (1455 triples in 1 batch(es))
# Inserted 497/969: delivery 10000161692 (1185 triples in 1 batch(es))
# Inserted 498/969: delivery 10000161697 (2232 triples in 1 batch(es))
# Inserted 499/969: delivery 10000161698 (129 triples in 1 batch(es))
# Inserted 500/969: delivery 10000161701 (4396 triples in 2 batch(es))
# Inserted 501/969: delivery 10000161710 (1135 triples in 1 batch(es))
# Inserted 502/969: delivery 10000161717 (1940 triples in 1 batch(es))
# Inserted 503/969: delivery 10000161719 (1549 triples in 1 batch(es))
# Inserted 504/969: delivery 10000161723 (8919 triples in 3 batch(es))
# Inserted 505/969: delivery 10000161742 (1562 triples in 1 batch(es))
# Inserted 506/969: delivery 10000161747 (3655 triples in 1 batch(es))
# Inserted 507/969: delivery 10000161777 (1701 triples in 1 batch(es))
# Inserted 508/969: delivery 10000161778 (1226 triples in 1 batch(es))
# Inserted 509/969: delivery 10000161779 (537 triples in 1 batch(es))
# Inserted 510/969: delivery 10000161791 (6634 triples in 2 batch(es))
# Inserted 511/969: delivery 10000161795 (2331 triples in 1 batch(es))
# Inserted 512/969: delivery 10000161798 (2331 triples in 1 batch(es))
# Inserted 513/969: delivery 10000161799 (2331 triples in 1 batch(es))
# Inserted 514/969: delivery 10000161805 (1535 triples in 1 batch(es))
# Inserted 515/969: delivery 10000161812 (1229 triples in 1 batch(es))
# Inserted 516/969: delivery 10000161816 (281 triples in 1 batch(es))
# Inserted 517/969: delivery 10000161823 (1100 triples in 1 batch(es))
# Inserted 518/969: delivery 10000161831 (134 triples in 1 batch(es))
# Inserted 519/969: delivery 10000161834 (1915 triples in 1 batch(es))
# Inserted 520/969: delivery 10000161835 (983 triples in 1 batch(es))
# Inserted 521/969: delivery 10000161841 (1176 triples in 1 batch(es))
# Inserted 522/969: delivery 10000161845 (1477 triples in 1 batch(es))
# Inserted 523/969: delivery 10000161847 (1068 triples in 1 batch(es))
# Inserted 524/969: delivery 10000161854 (174 triples in 1 batch(es))
# Inserted 525/969: delivery 10000161858 (7789 triples in 2 batch(es))
# Inserted 526/969: delivery 10000161860 (549 triples in 1 batch(es))
# Inserted 527/969: delivery 10000161861 (510 triples in 1 batch(es))
# Inserted 528/969: delivery 10000161862 (536 triples in 1 batch(es))
# Inserted 529/969: delivery 10000161863 (445 triples in 1 batch(es))
# Inserted 530/969: delivery 10000161864 (354 triples in 1 batch(es))
# Inserted 531/969: delivery 10000161865 (432 triples in 1 batch(es))
# Inserted 532/969: delivery 10000161866 (471 triples in 1 batch(es))
# Inserted 533/969: delivery 10000161867 (848 triples in 1 batch(es))
# Inserted 534/969: delivery 10000161868 (315 triples in 1 batch(es))
# Inserted 535/969: delivery 10000161869 (627 triples in 1 batch(es))
# Inserted 536/969: delivery 10000161871 (757 triples in 1 batch(es))
# Inserted 537/969: delivery 10000161872 (354 triples in 1 batch(es))
# Inserted 538/969: delivery 10000161873 (510 triples in 1 batch(es))
# Inserted 539/969: delivery 10000161882 (2855 triples in 1 batch(es))
# Inserted 540/969: delivery 10000161883 (2855 triples in 1 batch(es))
# Inserted 541/969: delivery 10000161885 (1973 triples in 1 batch(es))
# Inserted 542/969: delivery 10000161887 (454 triples in 1 batch(es))
# Inserted 543/969: delivery 10000161889 (2658 triples in 1 batch(es))
# Inserted 544/969: delivery 10000161892 (3827 triples in 1 batch(es))
# Inserted 545/969: delivery 10000161897 (646 triples in 1 batch(es))
# Inserted 546/969: delivery 10000161898 (1859 triples in 1 batch(es))
# Inserted 547/969: delivery 10000161899 (4216 triples in 2 batch(es))
# Inserted 548/969: delivery 10000161900 (4216 triples in 2 batch(es))
# Inserted 549/969: delivery 10000161901 (1846 triples in 1 batch(es))
# Inserted 550/969: delivery 10000161905 (3059 triples in 1 batch(es))
# Inserted 551/969: delivery 10000161906 (3307 triples in 1 batch(es))
# Inserted 552/969: delivery 10000161907 (3306 triples in 1 batch(es))
# Inserted 553/969: delivery 10000161908 (2929 triples in 1 batch(es))
# Inserted 554/969: delivery 10000161912 (603 triples in 1 batch(es))
# Inserted 555/969: delivery 10000161913 (2296 triples in 1 batch(es))
# Inserted 556/969: delivery 10000161915 (1514 triples in 1 batch(es))
# Inserted 557/969: delivery 10000161917 (2305 triples in 1 batch(es))
# Inserted 558/969: delivery 10000161924 (1514 triples in 1 batch(es))
# Inserted 559/969: delivery 10000161932 (1562 triples in 1 batch(es))
# Inserted 560/969: delivery 10000161935 (704 triples in 1 batch(es))
# Inserted 561/969: delivery 10000161939 (742 triples in 1 batch(es))
# Inserted 562/969: delivery 10000161940 (117 triples in 1 batch(es))
# Inserted 563/969: delivery 10000161949 (2266 triples in 1 batch(es))
# Inserted 564/969: delivery 10000161957 (264 triples in 1 batch(es))
# Inserted 565/969: delivery 10000161966 (251 triples in 1 batch(es))
# Inserted 566/969: delivery 10000161967 (4749 triples in 2 batch(es))
# Inserted 567/969: delivery 10000161968 (56 triples in 1 batch(es))
# Inserted 568/969: delivery 10000161970 (95 triples in 1 batch(es))
# Inserted 569/969: delivery 10000161972 (95 triples in 1 batch(es))
# Inserted 570/969: delivery 10000161973 (3534 triples in 1 batch(es))
# Inserted 571/969: delivery 10000161974 (3534 triples in 1 batch(es))
# Inserted 572/969: delivery 10000161977 (109 triples in 1 batch(es))
# Inserted 573/969: delivery 10000161981 (1499 triples in 1 batch(es))
# Inserted 574/969: delivery 10000161985 (153 triples in 1 batch(es))
# Inserted 575/969: delivery 10000161987 (132 triples in 1 batch(es))
# Inserted 576/969: delivery 10000161989 (105 triples in 1 batch(es))
# Inserted 577/969: delivery 10000162002 (82 triples in 1 batch(es))
# Inserted 578/969: delivery 10000162012 (1241 triples in 1 batch(es))
# Inserted 579/969: delivery 10000162017 (171 triples in 1 batch(es))
# Inserted 580/969: delivery 10000162021 (2695 triples in 1 batch(es))
# Inserted 581/969: delivery 10000162048 (1107 triples in 1 batch(es))
# Inserted 582/969: delivery 10000162055 (875 triples in 1 batch(es))
# Inserted 583/969: delivery 10000162106 (2916 triples in 1 batch(es))
# Inserted 584/969: delivery 10000162130 (3011 triples in 1 batch(es))
# Inserted 585/969: delivery 10000162134 (203 triples in 1 batch(es))
# Inserted 586/969: delivery 10000162141 (325 triples in 1 batch(es))
# Inserted 587/969: delivery 10000162142 (2835 triples in 1 batch(es))
# Inserted 588/969: delivery 10000162145 (16997 triples in 5 batch(es))
# Inserted 589/969: delivery 10000162173 (1583 triples in 1 batch(es))
# Inserted 590/969: delivery 10000162185 (241 triples in 1 batch(es))
# Inserted 591/969: delivery 10000162234 (224 triples in 1 batch(es))
# Inserted 592/969: delivery 10000162262 (945 triples in 1 batch(es))
# Inserted 593/969: delivery 10000162268 (305 triples in 1 batch(es))
# Inserted 594/969: delivery 10000162269 (670 triples in 1 batch(es))
# Inserted 595/969: delivery 10000162281 (196 triples in 1 batch(es))
# Inserted 596/969: delivery 10000162286 (433 triples in 1 batch(es))
# Inserted 597/969: delivery 10000162295 (2160 triples in 1 batch(es))
# Inserted 598/969: delivery 10000162299 (1516 triples in 1 batch(es))
# Inserted 599/969: delivery 10000162309 (3150 triples in 1 batch(es))
# Inserted 600/969: delivery 10000162318 (2266 triples in 1 batch(es))
# Inserted 601/969: delivery 10000162319 (415 triples in 1 batch(es))
# Inserted 602/969: delivery 10000162320 (454 triples in 1 batch(es))
# Inserted 603/969: delivery 10000162325 (1298 triples in 1 batch(es))
# Inserted 604/969: delivery 10000162328 (4203 triples in 2 batch(es))
# Inserted 605/969: delivery 10000162329 (4396 triples in 2 batch(es))
# Inserted 606/969: delivery 10000162330 (4396 triples in 2 batch(es))
# Inserted 607/969: delivery 10000162331 (1187 triples in 1 batch(es))
# Inserted 608/969: delivery 10000162335 (4203 triples in 2 batch(es))
# Inserted 609/969: delivery 10000162340 (485 triples in 1 batch(es))
# Inserted 610/969: delivery 10000162343 (3306 triples in 1 batch(es))
# Inserted 611/969: delivery 10000162347 (1851 triples in 1 batch(es))
# Inserted 612/969: delivery 10000162355 (1846 triples in 1 batch(es))
# Inserted 613/969: delivery 10000162356 (10729 triples in 3 batch(es))
# Inserted 614/969: delivery 10000162365 (415 triples in 1 batch(es))
# Inserted 615/969: delivery 10000162368 (1291 triples in 1 batch(es))
# Inserted 616/969: delivery 10000162373 (2260 triples in 1 batch(es))
# Inserted 617/969: delivery 10000162375 (1848 triples in 1 batch(es))
# Inserted 618/969: delivery 10000162378 (2838 triples in 1 batch(es))
# Inserted 619/969: delivery 10000162379 (1393 triples in 1 batch(es))
# Inserted 620/969: delivery 10000162380 (1369 triples in 1 batch(es))
# Inserted 621/969: delivery 10000162381 (160 triples in 1 batch(es))
# Inserted 622/969: delivery 10000162383 (834 triples in 1 batch(es))
# Inserted 623/969: delivery 10000162386 (3226 triples in 1 batch(es))
# Inserted 624/969: delivery 10000162387 (435 triples in 1 batch(es))
# Inserted 625/969: delivery 10000162388 (3226 triples in 1 batch(es))
# Inserted 626/969: delivery 10000162389 (2206 triples in 1 batch(es))
# Inserted 627/969: delivery 10000162390 (2534 triples in 1 batch(es))
# Inserted 628/969: delivery 10000162391 (5761 triples in 2 batch(es))
# Inserted 629/969: delivery 10000162392 (1617 triples in 1 batch(es))
# Inserted 630/969: delivery 10000162397 (2487 triples in 1 batch(es))
# Inserted 631/969: delivery 10000162398 (1124 triples in 1 batch(es))
# Inserted 632/969: delivery 10000162402 (2029 triples in 1 batch(es))
# Inserted 633/969: delivery 10000162403 (1701 triples in 1 batch(es))
# Inserted 634/969: delivery 10000162404 (2735 triples in 1 batch(es))
# Inserted 635/969: delivery 10000162406 (121 triples in 1 batch(es))
# Inserted 636/969: delivery 10000162407 (524 triples in 1 batch(es))
# Inserted 637/969: delivery 10000162408 (1723 triples in 1 batch(es))
# Inserted 638/969: delivery 10000162410 (4030 triples in 2 batch(es))
# Inserted 639/969: delivery 10000162411 (2656 triples in 1 batch(es))
# Inserted 640/969: delivery 10000162412 (875 triples in 1 batch(es))
# Inserted 641/969: delivery 10000162416 (869 triples in 1 batch(es))
# Inserted 642/969: delivery 10000162419 (394 triples in 1 batch(es))
# Inserted 643/969: delivery 10000162421 (966 triples in 1 batch(es))
# Inserted 644/969: delivery 10000162422 (1477 triples in 1 batch(es))
# Inserted 645/969: delivery 10000162424 (1425 triples in 1 batch(es))
# Inserted 646/969: delivery 10000162425 (1174 triples in 1 batch(es))
# Inserted 647/969: delivery 10000162426 (2097 triples in 1 batch(es))
# Inserted 648/969: delivery 10000162427 (3676 triples in 1 batch(es))
# Inserted 649/969: delivery 10000162428 (2370 triples in 1 batch(es))
# Inserted 650/969: delivery 10000162431 (4 triples in 1 batch(es))
# Inserted 651/969: delivery 10000162432 (2123 triples in 1 batch(es))
# Inserted 652/969: delivery 10000162436 (1239 triples in 1 batch(es))
# Inserted 653/969: delivery 10000162437 (1239 triples in 1 batch(es))
# Inserted 654/969: delivery 10000162438 (5917 triples in 2 batch(es))
# Inserted 655/969: delivery 10000162440 (5917 triples in 2 batch(es))
# Inserted 656/969: delivery 10000162448 (795 triples in 1 batch(es))
# Inserted 657/969: delivery 10000162449 (1400 triples in 1 batch(es))
# Inserted 658/969: delivery 10000162450 (1339 triples in 1 batch(es))
# Inserted 659/969: delivery 10000162452 (1531 triples in 1 batch(es))
# Inserted 660/969: delivery 10000162459 (2376 triples in 1 batch(es))
# Inserted 661/969: delivery 10000162460 (3566 triples in 1 batch(es))
# Inserted 662/969: delivery 10000162461 (2736 triples in 1 batch(es))
# Inserted 663/969: delivery 10000162463 (1412 triples in 1 batch(es))
# Inserted 664/969: delivery 10000162467 (2472 triples in 1 batch(es))
# Inserted 665/969: delivery 10000162468 (2215 triples in 1 batch(es))
# Inserted 666/969: delivery 10000162470 (847 triples in 1 batch(es))
# Inserted 667/969: delivery 10000162471 (1068 triples in 1 batch(es))
# Inserted 668/969: delivery 10000162473 (2736 triples in 1 batch(es))
# Inserted 669/969: delivery 10000162474 (2847 triples in 1 batch(es))
# Inserted 670/969: delivery 10000162475 (2376 triples in 1 batch(es))
# Inserted 671/969: delivery 10000162476 (1032 triples in 1 batch(es))
# Inserted 672/969: delivery 10000162478 (3727 triples in 1 batch(es))
# Inserted 673/969: delivery 10000162479 (5012 triples in 2 batch(es))
# Inserted 674/969: delivery 10000162480 (1198 triples in 1 batch(es))
# Inserted 675/969: delivery 10000162481 (820 triples in 1 batch(es))
# Inserted 676/969: delivery 10000162483 (4101 triples in 2 batch(es))
# Inserted 677/969: delivery 10000162484 (3512 triples in 1 batch(es))
# Inserted 678/969: delivery 10000162486 (2964 triples in 1 batch(es))
# Inserted 679/969: delivery 10000162487 (222 triples in 1 batch(es))
# Inserted 680/969: delivery 10000162488 (1239 triples in 1 batch(es))
# Inserted 681/969: delivery 10000162489 (1990 triples in 1 batch(es))
# Inserted 682/969: delivery 10000162490 (1513 triples in 1 batch(es))
# Inserted 683/969: delivery 10000162491 (3455 triples in 1 batch(es))
# Inserted 684/969: delivery 10000162492 (805 triples in 1 batch(es))
# Inserted 685/969: delivery 10000162493 (434 triples in 1 batch(es))
# Inserted 686/969: delivery 10000162494 (3566 triples in 1 batch(es))
# Inserted 687/969: delivery 10000162495 (1443 triples in 1 batch(es))
# Inserted 688/969: delivery 10000162496 (2188 triples in 1 batch(es))
# Inserted 689/969: delivery 10000162497 (2747 triples in 1 batch(es))
# Inserted 690/969: delivery 10000162498 (2048 triples in 1 batch(es))
# Inserted 691/969: delivery 10000162502 (8407 triples in 3 batch(es))
# Inserted 692/969: delivery 10000162505 (1284 triples in 1 batch(es))
# Inserted 693/969: delivery 10000162506 (215 triples in 1 batch(es))
# Inserted 694/969: delivery 10000162507 (914 triples in 1 batch(es))
# Inserted 695/969: delivery 10000162510 (772 triples in 1 batch(es))
# Inserted 696/969: delivery 10000162512 (4203 triples in 2 batch(es))
# Inserted 697/969: delivery 10000162513 (1434 triples in 1 batch(es))
# Inserted 698/969: delivery 10000162514 (4404 triples in 2 batch(es))
# Inserted 699/969: delivery 10000162515 (1935 triples in 1 batch(es))
# Inserted 700/969: delivery 10000162518 (1024 triples in 1 batch(es))
# Inserted 701/969: delivery 10000162522 (1397 triples in 1 batch(es))
# ...
# Inserted 738/969: delivery 10000162576 (2851 triples in 1 batch(es))
# Inserted 739/969: delivery 10000162577 (82 triples in 1 batch(es))
# Inserted 740/969: delivery 10000162578 (2353 triples in 1 batch(es))
# Inserted 741/969: delivery 10000162579 (95 triples in 1 batch(es))
# Inserted 742/969: delivery 10000162580 (6812 triples in 2 batch(es))
# Inserted 743/969: delivery 10000162581 (6800 triples in 2 batch(es))
# Inserted 744/969: delivery 10000162582 (3655 triples in 1 batch(es))
# Inserted 745/969: delivery 10000162584 (1707 triples in 1 batch(es))
# Inserted 746/969: delivery 10000162585 (131 triples in 1 batch(es))
# Inserted 747/969: delivery 10000162586 (3723 triples in 1 batch(es))
# Inserted 748/969: delivery 10000162587 (782 triples in 1 batch(es))
# Inserted 749/969: delivery 10000162588 (1959 triples in 1 batch(es))
# Inserted 750/969: delivery 10000162589 (303 triples in 1 batch(es))
# Inserted 751/969: delivery 10000162590 (3826 triples in 1 batch(es))
# Inserted 752/969: delivery 10000162591 (576 triples in 1 batch(es))
# Inserted 753/969: delivery 10000162592 (498 triples in 1 batch(es))
# Inserted 754/969: delivery 10000162593 (2802 triples in 1 batch(es))
# Inserted 755/969: delivery 10000162595 (2801 triples in 1 batch(es))
# Inserted 756/969: delivery 10000162596 (5570 triples in 2 batch(es))
# Inserted 757/969: delivery 10000162598 (1935 triples in 1 batch(es))
# Inserted 758/969: delivery 10000162600 (2736 triples in 1 batch(es))
# Inserted 759/969: delivery 10000162601 (56 triples in 1 batch(es))
# Inserted 760/969: delivery 10000162603 (3803 triples in 1 batch(es))
# Inserted 761/969: delivery 10000162604 (3087 triples in 1 batch(es))
# Inserted 762/969: delivery 10000162605 (1920 triples in 1 batch(es))
# Inserted 763/969: delivery 10000162606 (7098 triples in 2 batch(es))
# Inserted 764/969: delivery 10000162607 (424 triples in 1 batch(es))
# Inserted 765/969: delivery 10000162608 (5524 triples in 2 batch(es))
# Inserted 766/969: delivery 10000162609 (4113 triples in 2 batch(es))
# Inserted 767/969: delivery 10000162610 (5524 triples in 2 batch(es))
# Inserted 768/969: delivery 10000162611 (9074 triples in 3 batch(es))
# Inserted 769/969: delivery 10000162612 (85 triples in 1 batch(es))
# Inserted 770/969: delivery 10000162613 (505 triples in 1 batch(es))
# Inserted 771/969: delivery 10000162614 (326 triples in 1 batch(es))
# Inserted 772/969: delivery 10000162616 (3305 triples in 1 batch(es))
# Inserted 773/969: delivery 10000162617 (2032 triples in 1 batch(es))
# Inserted 774/969: delivery 10000162618 (1213 triples in 1 batch(es))
# Inserted 775/969: delivery 10000162619 (1583 triples in 1 batch(es))
# Inserted 776/969: delivery 10000162620 (2847 triples in 1 batch(es))
# Inserted 777/969: delivery 10000162621 (202 triples in 1 batch(es))
# Inserted 778/969: delivery 10000162622 (4383 triples in 2 batch(es))
# Inserted 779/969: delivery 10000162623 (1504 triples in 1 batch(es))
# Inserted 780/969: delivery 10000162624 (1358 triples in 1 batch(es))
# Inserted 781/969: delivery 10000162625 (1358 triples in 1 batch(es))
# Inserted 782/969: delivery 10000162627 (1199 triples in 1 batch(es))
# Inserted 783/969: delivery 10000162628 (1199 triples in 1 batch(es))
# Inserted 784/969: delivery 10000162629 (56 triples in 1 batch(es))
# Inserted 785/969: delivery 10000162630 (134 triples in 1 batch(es))
# Inserted 786/969: delivery 10000162631 (1068 triples in 1 batch(es))
# Inserted 787/969: delivery 10000162632 (1722 triples in 1 batch(es))
# Inserted 788/969: delivery 10000162633 (55 triples in 1 batch(es))
# Inserted 789/969: delivery 10000162634 (1302 triples in 1 batch(es))
# Inserted 790/969: delivery 10000162635 (533 triples in 1 batch(es))
# Inserted 791/969: delivery 10000162636 (463 triples in 1 batch(es))
# Inserted 792/969: delivery 10000162638 (211 triples in 1 batch(es))
# Inserted 793/969: delivery 10000162639 (225 triples in 1 batch(es))
# Inserted 794/969: delivery 10000162640 (281 triples in 1 batch(es))
# Inserted 795/969: delivery 10000162641 (337 triples in 1 batch(es))
# Inserted 796/969: delivery 10000162642 (365 triples in 1 batch(es))
# Inserted 797/969: delivery 10000162643 (407 triples in 1 batch(es))
# Inserted 798/969: delivery 10000162644 (281 triples in 1 batch(es))
# Inserted 799/969: delivery 10000162645 (9087 triples in 3 batch(es))
# Inserted 800/969: delivery 10000162646 (1915 triples in 1 batch(es))
# Inserted 801/969: delivery 10000162647 (323 triples in 1 batch(es))
# Inserted 802/969: delivery 10000162649 (4737 triples in 2 batch(es))
# Inserted 803/969: delivery 10000162650 (658 triples in 1 batch(es))
# Inserted 804/969: delivery 10000162652 (3375 triples in 1 batch(es))
# Inserted 805/969: delivery 10000162653 (1369 triples in 1 batch(es))
# Inserted 806/969: delivery 10000162654 (57 triples in 1 batch(es))
# Inserted 807/969: delivery 10000162655 (2144 triples in 1 batch(es))
# Inserted 808/969: delivery 10000162656 (1954 triples in 1 batch(es))
# Inserted 809/969: delivery 10000162658 (4888 triples in 2 batch(es))
# Inserted 810/969: delivery 10000162660 (127 triples in 1 batch(es))
# Inserted 811/969: delivery 10000162662 (1278 triples in 1 batch(es))
# Inserted 812/969: delivery 10000162663 (1931 triples in 1 batch(es))
# Inserted 813/969: delivery 10000162664 (2111 triples in 1 batch(es))
# Inserted 814/969: delivery 10000162666 (2410 triples in 1 batch(es))
# Inserted 815/969: delivery 10000162667 (5003 triples in 2 batch(es))
# Inserted 816/969: delivery 10000162668 (177 triples in 1 batch(es))
# Inserted 817/969: delivery 10000162669 (3315 triples in 1 batch(es))
# Inserted 818/969: delivery 10000162670 (262 triples in 1 batch(es))
# Inserted 819/969: delivery 10000162671 (90 triples in 1 batch(es))
# Inserted 820/969: delivery 10000162672 (3826 triples in 1 batch(es))
# Inserted 821/969: delivery 10000162673 (3081 triples in 1 batch(es))
# Inserted 822/969: delivery 10000162674 (9958 triples in 3 batch(es))
# Inserted 823/969: delivery 10000162675 (446 triples in 1 batch(es))
# Inserted 824/969: delivery 10000162677 (1679 triples in 1 batch(es))
# Inserted 825/969: delivery 10000162678 (1679 triples in 1 batch(es))
# Inserted 826/969: delivery 10000162679 (1422 triples in 1 batch(es))
# Inserted 827/969: delivery 10000162681 (202 triples in 1 batch(es))
# Inserted 828/969: delivery 10000162683 (1757 triples in 1 batch(es))
# Inserted 829/969: delivery 10000162684 (1757 triples in 1 batch(es))
# Inserted 830/969: delivery 10000162685 (841 triples in 1 batch(es))
# Inserted 831/969: delivery 10000162687 (2383 triples in 1 batch(es))
# Inserted 832/969: delivery 10000162688 (1967 triples in 1 batch(es))
# Inserted 833/969: delivery 10000162689 (756 triples in 1 batch(es))
# Inserted 834/969: delivery 10000162690 (4389 triples in 2 batch(es))
# Inserted 835/969: delivery 10000162691 (1239 triples in 1 batch(es))
# Inserted 836/969: delivery 10000162692 (638 triples in 1 batch(es))
# Inserted 837/969: delivery 10000162693 (161 triples in 1 batch(es))
# Inserted 838/969: delivery 10000162694 (7492 triples in 2 batch(es))
# Inserted 839/969: delivery 10000162695 (4255 triples in 2 batch(es))
# Inserted 840/969: delivery 10000162699 (3111 triples in 1 batch(es))
# Inserted 841/969: delivery 10000162700 (182 triples in 1 batch(es))
# Inserted 842/969: delivery 10000162701 (769 triples in 1 batch(es))
# Inserted 843/969: delivery 10000162703 (2992 triples in 1 batch(es))
# Inserted 844/969: delivery 10000162704 (1332 triples in 1 batch(es))
# Inserted 845/969: delivery 10000162706 (5175 triples in 2 batch(es))
# Inserted 846/969: delivery 10000162707 (343 triples in 1 batch(es))
# Inserted 847/969: delivery 10000162708 (1457 triples in 1 batch(es))
# Inserted 848/969: delivery 10000162709 (2235 triples in 1 batch(es))
# Inserted 849/969: delivery 10000162711 (66 triples in 1 batch(es))
# Inserted 850/969: delivery 10000162712 (871 triples in 1 batch(es))
# Inserted 851/969: delivery 10000162714 (1835 triples in 1 batch(es))
# Inserted 852/969: delivery 10000162715 (2916 triples in 1 batch(es))
# Inserted 853/969: delivery 10000162716 (3444 triples in 1 batch(es))
# Inserted 854/969: delivery 10000162717 (241 triples in 1 batch(es))
# Inserted 855/969: delivery 10000162720 (2914 triples in 1 batch(es))
# Inserted 856/969: delivery 10000162721 (54 triples in 1 batch(es))
# Inserted 857/969: delivery 10000162722 (2058 triples in 1 batch(es))
# Inserted 858/969: delivery 10000162724 (69 triples in 1 batch(es))
# Inserted 859/969: delivery 10000162726 (1535 triples in 1 batch(es))
# Inserted 860/969: delivery 10000162728 (2705 triples in 1 batch(es))
# Inserted 861/969: delivery 10000162729 (3955 triples in 1 batch(es))
# Inserted 862/969: delivery 10000162730 (1396 triples in 1 batch(es))
# Inserted 863/969: delivery 10000162731 (5370 triples in 2 batch(es))
# Inserted 864/969: delivery 10000162732 (2721 triples in 1 batch(es))
# Inserted 865/969: delivery 10000162733 (2721 triples in 1 batch(es))
# Inserted 866/969: delivery 10000162734 (2721 triples in 1 batch(es))
# Inserted 867/969: delivery 10000162735 (2773 triples in 1 batch(es))
# Inserted 868/969: delivery 10000162736 (1383 triples in 1 batch(es))
# Inserted 869/969: delivery 10000162737 (1524 triples in 1 batch(es))
# Inserted 870/969: delivery 10000162738 (1056 triples in 1 batch(es))
# Inserted 871/969: delivery 10000162739 (1968 triples in 1 batch(es))
# Inserted 872/969: delivery 10000162740 (2383 triples in 1 batch(es))
# Inserted 873/969: delivery 10000162741 (545 triples in 1 batch(es))
# Inserted 874/969: delivery 10000162742 (143 triples in 1 batch(es))
# Inserted 875/969: delivery 10000162743 (1892 triples in 1 batch(es))
# Inserted 876/969: delivery 10000162744 (1395 triples in 1 batch(es))
# Inserted 877/969: delivery 10000162745 (6634 triples in 2 batch(es))
# Inserted 878/969: delivery 10000162746 (2803 triples in 1 batch(es))
# Inserted 879/969: delivery 10000162747 (4881 triples in 2 batch(es))
# Inserted 880/969: delivery 10000162748 (323 triples in 1 batch(es))
# Inserted 881/969: delivery 10000162749 (4881 triples in 2 batch(es))
# Inserted 882/969: delivery 10000162753 (1201 triples in 1 batch(es))
# Inserted 883/969: delivery 10000162755 (1284 triples in 1 batch(es))
# Inserted 884/969: delivery 10000162756 (3039 triples in 1 batch(es))
# Inserted 885/969: delivery 10000162757 (3039 triples in 1 batch(es))
# Inserted 886/969: delivery 10000162758 (2721 triples in 1 batch(es))
# Inserted 887/969: delivery 10000162759 (108 triples in 1 batch(es))
# Inserted 888/969: delivery 10000162760 (1466 triples in 1 batch(es))
# Inserted 889/969: delivery 10000162761 (111 triples in 1 batch(es))
# Inserted 890/969: delivery 10000162763 (1783 triples in 1 batch(es))
# Inserted 891/969: delivery 10000162764 (1538 triples in 1 batch(es))
# Inserted 892/969: delivery 10000162765 (912 triples in 1 batch(es))
# Inserted 893/969: delivery 10000162766 (3984 triples in 1 batch(es))
# Inserted 894/969: delivery 10000162767 (16948 triples in 5 batch(es))
# Inserted 895/969: delivery 10000162768 (1852 triples in 1 batch(es))
# Inserted 896/969: delivery 10000162769 (3843 triples in 1 batch(es))
# Inserted 897/969: delivery 10000162770 (1852 triples in 1 batch(es))
# Inserted 898/969: delivery 10000162771 (1524 triples in 1 batch(es))
# Inserted 899/969: delivery 10000162773 (886 triples in 1 batch(es))
# Inserted 900/969: delivery 10000162775 (1276 triples in 1 batch(es))
# Inserted 901/969: delivery 10000162776 (1963 triples in 1 batch(es))
# Inserted 902/969: delivery 10000162777 (1185 triples in 1 batch(es))
# Inserted 903/969: delivery 10000162778 (1410 triples in 1 batch(es))
# Inserted 904/969: delivery 10000162779 (2270 triples in 1 batch(es))
# Inserted 905/969: delivery 10000162780 (2270 triples in 1 batch(es))
# Inserted 906/969: delivery 10000162781 (2598 triples in 1 batch(es))
# Inserted 907/969: delivery 10000162782 (7608 triples in 2 batch(es))
# Inserted 908/969: delivery 10000162783 (5012 triples in 2 batch(es))
# Inserted 909/969: delivery 10000162784 (123 triples in 1 batch(es))
# Inserted 910/969: delivery 10000162786 (1229 triples in 1 batch(es))
# Inserted 911/969: delivery 10000162787 (2641 triples in 1 batch(es))
# Inserted 912/969: delivery 10000162788 (1484 triples in 1 batch(es))
# Inserted 913/969: delivery 10000162789 (132 triples in 1 batch(es))
# Inserted 914/969: delivery 10000162790 (1986 triples in 1 batch(es))
# Inserted 915/969: delivery 10000162791 (2287 triples in 1 batch(es))
# Inserted 916/969: delivery 10000162792 (2486 triples in 1 batch(es))
# Inserted 917/969: delivery 10000162793 (1829 triples in 1 batch(es))
# Inserted 918/969: delivery 10000162794 (256 triples in 1 batch(es))
# Inserted 919/969: delivery 10000162795 (176 triples in 1 batch(es))
# Inserted 920/969: delivery 10000162796 (2886 triples in 1 batch(es))
# Inserted 921/969: delivery 10000162797 (2210 triples in 1 batch(es))
# Inserted 922/969: delivery 10000162798 (823 triples in 1 batch(es))
# Inserted 923/969: delivery 10000162799 (1640 triples in 1 batch(es))
# Inserted 924/969: delivery 10000162800 (4132 triples in 2 batch(es))
# Inserted 925/969: delivery 10000162801 (1210 triples in 1 batch(es))
# Inserted 926/969: delivery 10000162804 (2232 triples in 1 batch(es))
# Inserted 927/969: delivery 10000162805 (3087 triples in 1 batch(es))
# Inserted 928/969: delivery 10000162806 (2171 triples in 1 batch(es))
# Inserted 929/969: delivery 10000162809 (231 triples in 1 batch(es))
# Inserted 930/969: delivery 10000162810 (757 triples in 1 batch(es))
# Inserted 931/969: delivery 10000162811 (2943 triples in 1 batch(es))
# Inserted 932/969: delivery 10000162813 (1440 triples in 1 batch(es))
# Inserted 933/969: delivery 10000162814 (2166 triples in 1 batch(es))
# Inserted 934/969: delivery 10000162815 (1966 triples in 1 batch(es))
# Inserted 935/969: delivery 10000162816 (3294 triples in 1 batch(es))
# Inserted 936/969: delivery 10000162817 (1478 triples in 1 batch(es))
# Inserted 937/969: delivery 10000162818 (239 triples in 1 batch(es))
# Inserted 938/969: delivery 10000162821 (3369 triples in 1 batch(es))
# Inserted 939/969: delivery 10000162822 (3369 triples in 1 batch(es))
# Inserted 940/969: delivery 10000162824 (2914 triples in 1 batch(es))
# Inserted 941/969: delivery 10000162837 (784 triples in 1 batch(es))
# Inserted 942/969: delivery 10000162838 (2258 triples in 1 batch(es))
# Inserted 943/969: delivery 10000162843 (965 triples in 1 batch(es))
# Inserted 944/969: delivery 10000162851 (2283 triples in 1 batch(es))
# Inserted 945/969: delivery 10000162878 (899 triples in 1 batch(es))
# Inserted 946/969: delivery 10000162892 (2300 triples in 1 batch(es))
# Inserted 947/969: delivery 10000162898 (93 triples in 1 batch(es))
# Inserted 948/969: delivery 10000162899 (1354 triples in 1 batch(es))
# Inserted 949/969: delivery 10000162935 (589 triples in 1 batch(es))
# Inserted 950/969: delivery 10000162938 (1696 triples in 1 batch(es))
# Inserted 951/969: delivery 10000162939 (771 triples in 1 batch(es))
# Inserted 952/969: delivery 10000162987 (756 triples in 1 batch(es))
# Inserted 953/969: delivery 10000163000 (3087 triples in 1 batch(es))
# Inserted 954/969: delivery 10000163027 (784 triples in 1 batch(es))
# Inserted 955/969: delivery 10000163040 (1778 triples in 1 batch(es))
# Inserted 956/969: delivery 10000163064 (5165 triples in 2 batch(es))
# Inserted 957/969: delivery 10000163076 (1569 triples in 1 batch(es))
# Inserted 958/969: delivery 10000163077 (269 triples in 1 batch(es))
# Inserted 959/969: delivery 10000163152 (1003 triples in 1 batch(es))
# Inserted 960/969: delivery 10000163172 (615 triples in 1 batch(es))
# Inserted 961/969: delivery 10000163394 (496 triples in 1 batch(es))
# Inserted 962/969: delivery 10000163417 (1565 triples in 1 batch(es))
# Inserted 963/969: delivery 10000163519 (1583 triples in 1 batch(es))
# Inserted 964/969: delivery 10000163529 (2238 triples in 1 batch(es))
# Inserted 965/969: delivery 10000163532 (1089 triples in 1 batch(es))
# Inserted 966/969: delivery 10000163535 (1940 triples in 1 batch(es))
# Inserted 967/969: delivery 10000163563 (4255 triples in 2 batch(es))
# Inserted 968/969: delivery 10000163575 (1089 triples in 1 batch(es))
# Inserted 969/969: delivery 10000163579 (3930 triples in 1 batch(es))
#
# Successfully inserted: 969
# Failed: 0

# %% [markdown]
# ## 6. Verify the inserted hierarchy

# %%
verification_query = f"""
{PREFIXES}

SELECT
  (COUNT(DISTINCT ?delivery) AS ?deliveries)
  (COUNT(DISTINCT ?bd) AS ?beleidsdoelstellingen)
  (COUNT(DISTINCT ?ap) AS ?actieplannen)
  (COUNT(DISTINCT ?action) AS ?acties)
WHERE {{
  GRAPH <{PUBLIC_GRAPH}> {{
    # ?delivery
      a vmm:Aanlevering ;
      eli:has_member

    # ?bd
      a eli:ComplexWork ;
      eli:work_type vmm:Beleidsdoelstelling ;
      eli:is_realized_by ?bdExpression .

    OPTIONAL {{
      # ?bd eli:has_member ?ap .
      # ?ap
        a eli:ComplexWork ;
        eli:work_type vmm:Actieplan ;
        eli:is_realized_by ?apExpression .

      OPTIONAL {{
        # ?ap eli:has_member ?action .
        # ?action
          a eli:Work ;
          eli:work_type vmm:Actie ;
          eli:is_realized_by ?actionExpression .
      }}
    }}
  }}
}}
"""

if DRY_RUN:
    print("Skip store verification during dry run.")
else:
    results = sparql_query(verification_query)
    if not results:
        print("No verification result returned.")
    else:
        result = results[0]
        print("Current MJP hierarchy in the public graph:")
        for key in (
            "deliveries",
            "beleidsdoelstellingen",
            "actieplannen",
            "acties",
        ):
            print(f"  {key}: {result.get(key, {}).get('value', '0')}")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[17], line 42
#      40     print("Skip store verification during dry run.")
#      41 else:
# ---> 42     results = sparql_query(verification_query)
#      43     if not results:
#      44         print("No verification result returned.")
#
# Cell In[12], line 19, in sparql_query(query)
#      13 """Execute a SPARQL SELECT query and return its bindings."""
#      14 response = requests.get(
#      15     SPARQL_URL,
#      16     params={"query": query, "format": "application/sparql-results+json"},
#      17     timeout=120,
#      18 )
# ---> 19 response.raise_for_status()
#      20 return response.json().get("results", {}).get("bindings", [])
#
# File c:\Users\stefa\anaconda3\envs\abb\Lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: http://localhost:8890/sparql?query=%0APREFIX+dct%3A++++%3Chttp%3A%2F%2Fpurl.org%2Fdc%2Fterms%2F%3E%0APREFIX+eli%3A++++%3Chttp%3A%2F%2Fdata.europa.eu%2Feli%2Fontology%23%3E%0APREFIX+epvoc%3A++%3Chttps%3A%2F%2Fdata.europarl.europa.eu%2Fdef%2Fepvoc%23%3E%0APREFIX+mu%3A+++++%3Chttp%3A%2F%2Fmu.semte.ch%2Fvocabularies%2Fcore%2F%3E%0APREFIX+schema%3A+%3Chttps%3A%2F%2Fschema.org%2F%3E%0APREFIX+vmm%3A++++%3Chttp%3A%2F%2Flblod.data.gift%2Fvocabularies%2Fvmm%2F%3E%0APREFIX+xsd%3A++++%3Chttp%3A%2F%2Fwww.w3.org%2F2001%2FXMLSchema%23%3E%0A%0ASELECT%0A++%28COUNT%28DISTINCT+%3Fdelivery%29+AS+%3Fdeliveries%29%0A++%28COUNT%28DISTINCT+%3Fbd%29+AS+%3Fbeleidsdoelstellingen%29%0A++%28COUNT%28DISTINCT+%3Fap%29+AS+%3Factieplannen%29%0A++%28COUNT%28DISTINCT+%3Faction%29+AS+%3Facties%29%0AWHERE+%7B%0A++GRAPH+%3Chttp%3A%2F%2Fmu.semte.ch%2Fgraphs%2Fpublic%3E+%7B%0A++++%3Fdelivery%0A++++++a+vmm%3AAanlevering+%3B%0A++++++eli%3Ahas_member%0A%0A++++%3Fbd%0A++++++a+eli%3AComplexWork+%3B%0A++++++eli%3Awork_type+vmm%3ABeleidsdoelstelling+%3B%0A++++++eli%3Ais_realized_by+%3FbdExpression+.%0A%0A++++OPTIONAL+%7B%0A++++++%3Fbd+eli%3Ahas_member+%3Fap+.%0A++++++%3Fap%0A++++++++a+eli%3AComplexWork+%3B%0A++++++++eli%3Awork_type+vmm%3AActieplan+%3B%0A++++++++eli%3Ais_realized_by+%3FapExpression+.%0A%0A++++++OPTIONAL+%7B%0A++++++++%3Fap+eli%3Ahas_member+%3Faction+.%0A++++++++%3Faction%0A++++++++++a+eli%3AWork+%3B%0A++++++++++eli%3Awork_type+vmm%3AActie+%3B%0A++++++++++eli%3Ais_realized_by+%3FactionExpression+.%0A++++++%7D%0A++++%7D%0A++%7D%0A%7D%0A&format=application%2Fsparql-results%2Bjson

# %%
sample_query = f"""
{PREFIXES}

SELECT
  # ?aanleveringId
  # ?beleidsdoelstellingId
  # ?beleidsdoelstellingBeschrijving
  # ?actieplanId
  # ?actieplanBeschrijving
  # ?actieId
  # ?actieBeschrijving
WHERE {{
  GRAPH <{PUBLIC_GRAPH}> {{
    # ?delivery
      a vmm:Aanlevering ;
      dct:identifier ?aanleveringId ;
      eli:has_member ?bd .

    # ?bd
      dct:identifier ?beleidsdoelstellingId ;
      eli:is_realized_by ?bdExpression ;
      eli:has_member ?ap .

    OPTIONAL {{
      # ?bdExpression
        eli:description
        # ?beleidsdoelstellingBeschrijving .
    }}

    # ?ap
      dct:identifier ?actieplanId ;
      eli:is_realized_by ?apExpression ;
      eli:has_member ?action .

    OPTIONAL {{
      # ?apExpression eli:description ?actieplanBeschrijving .
    }}

    # ?action
      dct:identifier ?actieId ;
      eli:is_realized_by ?actionExpression .

    OPTIONAL {{
      # ?actionExpression eli:description ?actieBeschrijving .
    }}
  }}
}}
ORDER BY
  # ?aanleveringId
  # ?beleidsdoelstellingId
  # ?actieplanId
  # ?actieId
LIMIT 50
"""

if DRY_RUN:
    print("Skip sample query during dry run.")
else:
    rows = sparql_query(sample_query)
    print(f"Returned {len(rows)} hierarchy rows.\n")
    for row in rows:
        print(
            row.get("aanleveringId", {}).get("value", "?"),
            "\u2192",
            row.get("beleidsdoelstellingId", {}).get("value", "?"),
            "\u2192",
            row.get("actieplanId", {}).get("value", "?"),
            "\u2192",
            row.get("actieId", {}).get("value", "?"),
        )
# Out:
# Returned 50 hierarchy rows.
#
# 10000158105 → 2315856 → 5270327 → 14633581
# 10000158105 → 2315856 → 5270327 → 14633582
# 10000158105 → 2315856 → 5270327 → 14633583
# 10000158105 → 2315856 → 5270327 → 14633584
# 10000158105 → 2315856 → 5270328 → 14633585
# 10000158105 → 2315856 → 5270328 → 14633586
# 10000158105 → 2315856 → 5270328 → 14633587
# 10000158105 → 2315856 → 5270328 → 14633588
# 10000158105 → 2315856 → 5270328 → 14633589
# 10000158105 → 2315856 → 5270328 → 14633590
# 10000158105 → 2315856 → 5270328 → 14633591
# 10000158105 → 2315856 → 5270328 → 14633592
# 10000158105 → 2315856 → 5270328 → 14633593
# 10000158105 → 2315856 → 5270328 → 14633594
# 10000158105 → 2315856 → 5270328 → 14633595
# 10000158105 → 2315856 → 5270328 → 14633596
# 10000158105 → 2315856 → 5270329 → 14633597
# 10000160197 → 2339882 → 5354182 → 15027800
# 10000160197 → 2339882 → 5354182 → 15027801
# 10000160197 → 2339882 → 5354182 → 15027802
# 10000160197 → 2339882 → 5354182 → 15027803
# 10000160197 → 2339882 → 5354182 → 15027804
# 10000160197 → 2339882 → 5354182 → 15027805
# 10000160197 → 2339882 → 5354182 → 15027806
# 10000160197 → 2339882 → 5354182 → 15027807
# 10000160197 → 2339882 → 5354182 → 15027808
# 10000160197 → 2339882 → 5354182 → 15027809
# 10000160197 → 2339882 → 5354182 → 15027810
# 10000160197 → 2339882 → 5354183 → 15027811
# 10000160197 → 2339882 → 5354183 → 15027812
# 10000160197 → 2339882 → 5354183 → 15027813
# 10000160197 → 2339882 → 5354183 → 15027814
# 10000160197 → 2339882 → 5354183 → 15027815
# 10000160197 → 2339882 → 5354183 → 15027816
# 10000160197 → 2339882 → 5354183 → 15027817
# 10000160197 → 2339882 → 5354184 → 15027818
# 10000160197 → 2339882 → 5354184 → 15027819
# 10000160197 → 2339882 → 5354184 → 15027820
# 10000160197 → 2339882 → 5354184 → 15027821
# 10000160197 → 2339882 → 5354184 → 15027822
# 10000160197 → 2339882 → 5354184 → 15027823
# 10000160197 → 2339882 → 5354184 → 15027824
# 10000160197 → 2339882 → 5354184 → 15027825
# 10000160197 → 2339882 → 5354184 → 15027826
# 10000160197 → 2339882 → 5354185 → 15027827
# 10000160197 → 2339882 → 5354185 → 15027828
# 10000160197 → 2339882 → 5354185 → 15027829
# 10000160197 → 2339882 → 5354185 → 15027830
# 10000160197 → 2339882 → 5354185 → 15027831
# 10000160197 → 2339882 → 5354185 → 15027832

# %% [markdown]
# ## 7. Data-model integrity checks

# %%
integrity_query = f"""
{PREFIXES}

SELECT ?problem (COUNT(DISTINCT ?resource) AS ?count)
WHERE {{
  GRAPH <{PUBLIC_GRAPH}> {{
    {{
      # ?resource
        eli:work_type ?workType .
      VALUES ?workType {{
        vmm:Beleidsdoelstelling
        vmm:Actieplan
        vmm:Actie
      }}
      FILTER NOT EXISTS {{
        # ?resource eli:is_realized_by ?expression .
        # ?expression a eli:Expression .
      }}
      BIND("Work without Expression" AS ?problem)
    }}
    UNION
    {{
      # ?resource
        eli:work_type vmm:Actieplan .
      FILTER NOT EXISTS {{
        # ?beleidsdoelstelling
          eli:has_member
          # ?resource .
      }}
      BIND("Actieplan without beleidsdoelstelling" AS ?problem)
    }}
    UNION
    {{
      # ?resource
        eli:work_type vmm:Actie .
      FILTER NOT EXISTS {{
        # ?actieplan eli:has_member ?resource .
      }}
      BIND("Actie without actieplan" AS ?problem)
    }}
  }}
}}
GROUP BY ?problem
ORDER BY ?problem
"""

if DRY_RUN:
    print("Skip integrity checks during dry run.")
else:
    problems = sparql_query(integrity_query)
    if not problems:
        print("No structural integrity problems found.")
    else:
        print("Integrity problems:")
        for problem in problems:
            print(
                f"  {problem['problem']['value']}: "
                f"{problem['count']['value']}"
            )

# %% [markdown]
# ## 8. Codelist evaluation job
#
# Create and trigger a codelist evaluation job targeting expression URIs from the
# deliveries inserted above. The pipeline flow is:
#
# ```text
# singleton-job → evaluation-split-tasks → annotate
# ```

# %%
import uuid
import subprocess
from datetime import datetime, timezone

JOBS_GRAPH = HARVESTING_GRAPH

JOB_OPERATION_EVALUATION = (
    "http://lblod.data.gift/id/jobs/concept/"
    "JobOperation/codelist-matching/evaluation"
)
TASK_OPERATION_SINGLETON = (
    "http://lblod.data.gift/id/jobs/concept/"
    "TaskOperation/singleton-job"
)
STATUS_BUSY = "http://redpencil.data.gift/id/concept/JobStatus/busy"
STATUS_SCHEDULED = "http://redpencil.data.gift/id/concept/JobStatus/scheduled"
STATUS_SUCCESS = "http://redpencil.data.gift/id/concept/JobStatus/success"
SELF_SERVICE_CREATOR = "http://lblod.data.gift/services/job-self-service"
TEXT_PROPERTY_PATH = "<https://data.europarl.europa.eu/def/epvoc#expressionContent>"

DOCKER_NETWORK = "app-vmm_default"

JOB_PREFIXES = PREFIXES + "\n" + """
PREFIX mu:    <http://mu.semte.ch/vocabularies/core/>
PREFIX adms:  <http://www.w3.org/ns/adms#>
PREFIX task:  <http://redpencil.data.gift/vocabularies/tasks/>
PREFIX cogs:  <http://vocab.deri.ie/cogs#>
PREFIX nfo:   <http://www.semanticdesktop.org/ontologies/2007/03/22/nfo#>
PREFIX ext:   <http://mu.semte.ch/vocabularies/ext/>
PREFIX sh:    <http://www.w3.org/ns/shacl#>
""".strip()


def rdf_string(value: str) -> str:
    """Encode a Python string as a SPARQL-compatible quoted literal."""
    return json.dumps(value, ensure_ascii=False)


def utc_timestamp() -> str:
    return (
        datetime.now(timezone.utc)
        .isoformat(timespec="milliseconds")
        .replace("+00:00", "Z")
    )


def send_delta(service_url: str, delta_payload: list[dict]) -> str:
    """Send a delta notification to a service via the docker network."""
    cmd = [
        "docker", "run", "--rm", "--network", DOCKER_NETWORK,
        "curlimages/curl:latest",
        "-s", "-o", "/dev/null", "-w", "%{http_code}",
        "-X", "POST", "-H", "Content-Type: application/json",
        "-d", json.dumps(delta_payload),
        service_url,
    ]
    proc = subprocess.run(cmd, capture_output=True, text=True, timeout=60)
    return proc.stdout.strip()


print("Codelist evaluation helpers loaded.")

# %%
def create_codelist_evaluation_job(
    *,
    expression_uris: list[str],
    concept_scheme_uri: str,
    expressions_graph: str = PUBLIC_GRAPH,
    confidence_threshold: float = 0,
    text_property_path: str = TEXT_PROPERTY_PATH,
) -> dict[str, str]:
    """
    Create a codelist evaluation job targeting one or more existing expressions.

    Mirrors the frontend: creates a SHACL NodeShape with sh:targetNode entries
    for each expression, then creates the job and initial singleton task.
    The job-controller pipeline handles the rest:
      singleton-job \u2192 evaluation-split-tasks \u2192 annotate
    """
    if not expression_uris:
        raise ValueError("At least one expression URI is required.")

    job_uuid = str(uuid.uuid4())
    task_uuid = str(uuid.uuid4())
    shape_uuid = str(uuid.uuid4())
    container_uuid = str(uuid.uuid4())

    job_uri = f"http://data.lblod.info/id/jobs/{job_uuid}"
    task_uri = f"http://data.lblod.info/id/tasks/{task_uuid}"
    shape_uri = f"http://data.lblod.info/id/node-shapes/{shape_uuid}"
    container_uri = f"http://data.lblod.info/id/data-containers/{container_uuid}"

    timestamp = utc_timestamp()

    target_nodes = " ;\n          ".join(
        f"sh:targetNode <{u}>" for u in expression_uris
    )

    insert_query = f"""
    {JOB_PREFIXES}
    INSERT DATA {{
      GRAPH <{JOBS_GRAPH}> {{
        <{shape_uri}>
          a sh:NodeShape ;
          mu:uuid {rdf_string(shape_uuid)} ;
          {target_nodes} .

        <{job_uri}>
          a cogs:Job, ext:AnnotationJob ;
          mu:uuid {rdf_string(job_uuid)} ;
          adms:status <{STATUS_BUSY}> ;
          task:operation <{JOB_OPERATION_EVALUATION}> ;
          dct:creator <{SELF_SERVICE_CREATOR}> ;
          dct:created "{timestamp}"^^xsd:dateTime ;
          dct:modified "{timestamp}"^^xsd:dateTime ;
          ext:codelist <{concept_scheme_uri}> ;
          ext:graphForTargets <{expressions_graph}> ;
          ext:shapeForTargets <{shape_uri}> ;
          ext:propertyPathForText {rdf_string(text_property_path)} ;
          ext:confidenceThreshold "{confidence_threshold}"^^xsd:decimal .

        <{task_uri}>
          a task:Task ;
          mu:uuid {rdf_string(task_uuid)} ;
          adms:status <{STATUS_SCHEDULED}> ;
          task:operation <{TASK_OPERATION_SINGLETON}> ;
          task:index "0" ;
          dct:isPartOf <{job_uri}> ;
          task:inputContainer <{container_uri}> ;
          dct:created "{timestamp}"^^xsd:dateTime ;
          dct:modified "{timestamp}"^^xsd:dateTime .

        <{container_uri}>
          a nfo:DataContainer ;
          mu:uuid {rdf_string(container_uuid)} .
      }}
    }}
    """

    sparql_update(insert_query)

    print(f"Job:   {job_uri}")
    print(f"Task:  {task_uri}")
    print(f"Shape: {shape_uri} ({len(expression_uris)} target expressions)")

    return {
        "job_uuid": job_uuid,
        "task_uuid": task_uuid,
        "job": job_uri,
        "task": task_uri,
        "shape": shape_uri,
        "container": container_uri,
    }


def trigger_job_pipeline(task_uuid: str, container_uri: str) -> None:
    """
    Trigger the codelist evaluation pipeline.

    The harvest_singleton-job service only handles harvesting tasks (with
    collections/remote data objects). For codelist evaluation jobs, we:
    1. Advance the singleton task to 'success' ourselves
    2. Notify the job-controller so it creates the next task (evaluation-split-tasks)
    3. The annotation-job-splitter and codelist-labeling pick it up from there
    """
    task_uri = f"http://data.lblod.info/id/tasks/{task_uuid}"

    # 1. Mark singleton task as success
    update_query = f"""
    {JOB_PREFIXES}
    DELETE {{
      GRAPH <{JOBS_GRAPH}> {{
        <{task_uri}> adms:status ?oldStatus ;
                     dct:modified ?oldModified .
      }}
    }}
    INSERT {{
      GRAPH <{JOBS_GRAPH}> {{
        <{task_uri}> adms:status <{STATUS_SUCCESS}> ;
                     dct:modified "{utc_timestamp()}"^^xsd:dateTime ;
                     task:resultsContainer <{container_uri}> .
      }}
    }}
    WHERE {{
      GRAPH <{JOBS_GRAPH}> {{
        <{task_uri}> adms:status ?oldStatus .
        OPTIONAL {{ <{task_uri}> dct:modified ?oldModified . }}
      }}
    }}
    """
    sparql_update(update_query)
    print(f"Singleton task {task_uuid} \u2192 success")

    # 2. Notify job-controller (creates evaluation-split-tasks)
    delta = [{
        "inserts": [{
            "subject": {"type": "uri", "value": task_uri},
            "predicate": {"type": "uri", "value": "http://www.w3.org/ns/adms#status"},
            "object": {"type": "uri", "value": STATUS_SUCCESS},
        }],
        "deletes": [{
            "subject": {"type": "uri", "value": task_uri},
            "predicate": {"type": "uri", "value": "http://www.w3.org/ns/adms#status"},
            "object": {"type": "uri", "value": STATUS_SCHEDULED},
        }],
    }]

    status = send_delta("http://job-controller/delta", delta)
    print(f"job-controller notified: HTTP {status}")

    # 3. Also notify annotation-job-splitter
    import time
    time.sleep(2)  # brief wait for job-controller to create next task
    scheduled_delta = [{
        "inserts": [{
            "subject": {"type": "uri", "value": "urn:placeholder"},
            "predicate": {"type": "uri", "value": "http://www.w3.org/ns/adms#status"},
            "object": {"type": "uri", "value": STATUS_SCHEDULED},
        }],
        "deletes": [],
    }]
    status = send_delta("http://annotation-job-splitter/delta", scheduled_delta)
    print(f"annotation-job-splitter notified: HTTP {status}")


print("Job creation functions defined.")

# %% [markdown]
# ### Create and run a codelist evaluation job
#
# Collect expression URIs from the deliveries inserted above, then create a job
# targeting them. Adjust `CODELIST_URI` and the delivery range as needed.

# %%
# Select a range of deliveries whose expressions to target.
start_index = 0
end_index = 20

# Collect all expression URIs from those deliveries.
target_expression_uris: list[str] = []
for _line, _delivery_id, triples in generated_updates[start_index:end_index]:
    for t in triples:
        # Expression triples follow the pattern <.../expression> a eli:Expression .
        if t.endswith("a eli:Expression ."):
            expr_uri = t.split(">")[0].lstrip("<")
            target_expression_uris.append(expr_uri)

print(f"Selected {len(target_expression_uris)} expressions for evaluation:")
for u in target_expression_uris[:5]:
    print(f"  {u}")
if len(target_expression_uris) > 5:
    print(f"  ... and {len(target_expression_uris) - 5} more")

# Create the job
result = create_codelist_evaluation_job(
    expression_uris=target_expression_uris,
    concept_scheme_uri=CODELIST_URI,
)

# %%
# Trigger the codelist evaluation pipeline.
# The harvest_singleton-job service only handles harvesting tasks,
# so for codelist jobs we advance the singleton task ourselves and
# let the job-controller take over.
trigger_job_pipeline(result["task_uuid"], result["container"])

# %% [markdown]
# # Fetch unanotated Actieplannen

# %%
# fetch all actieplan URIs which are not fully evaluated yet (i.e. not all actions have been annotated)

query = """

PREFIX eli: <http://data.europa.eu/eli/ontology#>
PREFIX vmm: <http://lblod.data.gift/vocabularies/vmm/>
PREFIX oa:  <http://www.w3.org/ns/oa#>

SELECT DISTINCT ?work ?expression
WHERE {
  # ?work
    eli:work_type vmm:Actieplan ;
    eli:is_realized_by ?expression .

  FILTER EXISTS {
    # ?work eli:has_member ?actie .
    # ?actie eli:is_realized_by ?actieExpression .
    # ?actieExpression a eli:Expression .

    FILTER NOT EXISTS {
      # ?annotation a oa:Annotation ;
                  oa:hasTarget ?actieExpression .
    }
  }
}
ORDER BY ?work

"""
sparql_results = sparql_query(query)
print(f"Found {len(sparql_results)} actieplan works with unevaluated actions:")
all_unprocessed_actieplan_uris = [r["expression"]["value"] for r in sparql_results]
for uri in all_unprocessed_actieplan_uris[1500:2500]:
    print(uri)
# Out:
# Found 23097 actieplan works with unevaluated actions:
# http://lblod.data.gift/vocabularies/vmm/actieplan/5393994/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5393995/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5393996/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5393997/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5393998/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5393999/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394000/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394001/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394002/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394003/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394004/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394005/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394006/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394007/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394008/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394009/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394010/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394011/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394012/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394013/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394014/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394015/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394016/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394017/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394018/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394019/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394020/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394021/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394022/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394023/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394024/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394025/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394026/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394027/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394028/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394029/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394030/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394031/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394032/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394033/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394034/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394035/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394036/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394037/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394038/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394039/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394040/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394041/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394042/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394043/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394044/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394045/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394046/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394047/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394048/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394049/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394050/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394051/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394052/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394053/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394054/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394055/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394056/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394057/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394058/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394059/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394060/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394061/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394062/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394063/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394064/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394065/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394066/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394067/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394068/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394069/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394070/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394071/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394072/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394074/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394075/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394076/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394077/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394078/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394079/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394080/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394081/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394082/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394083/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394084/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394085/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394086/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394087/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394088/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394089/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394090/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394091/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394092/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394093/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394094/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394095/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394096/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394097/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394098/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394099/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394100/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394101/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394102/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394103/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394104/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394105/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394106/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394107/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394108/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394109/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394110/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394111/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394116/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394117/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394118/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394119/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394120/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394121/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394122/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394123/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394124/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394125/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394126/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394127/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394128/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394129/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394130/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394131/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394132/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394133/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394134/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394135/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394136/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394137/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394138/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394139/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394140/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394141/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394142/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394143/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394144/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394145/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394146/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394147/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394148/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394149/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394150/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394151/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394152/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394153/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394154/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394155/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394156/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394157/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394158/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394159/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394160/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394161/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394162/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394163/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394169/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394170/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394171/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394172/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394173/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394174/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394175/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394176/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394177/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394178/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394179/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394180/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394181/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394182/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394183/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394184/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394185/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394186/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394187/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394188/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394189/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394190/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394191/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394192/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394193/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394194/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394195/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394196/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394197/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394198/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394199/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394200/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394201/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394202/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394203/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394204/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394205/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394206/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394207/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394208/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394209/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394210/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394211/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394212/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394213/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394214/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394215/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394216/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394217/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394218/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394219/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394220/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394221/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394222/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394223/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394224/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394225/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394226/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394227/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394228/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394229/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394230/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394231/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394232/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394233/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394234/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394235/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394236/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394237/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394238/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394239/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394240/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394241/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394242/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394243/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394244/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394245/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394246/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394247/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394248/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394249/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394250/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394251/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394252/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394253/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394254/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394255/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394256/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394257/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394258/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394259/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394260/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394261/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394262/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394263/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394264/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394265/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394266/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394267/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394268/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394269/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394270/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394271/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394272/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394273/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394274/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394275/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394400/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394401/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394402/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394403/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394404/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394405/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394406/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394407/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394408/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394409/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394410/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394411/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394412/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394413/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394414/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394415/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394416/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394417/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394418/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394419/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394420/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394421/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394422/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394423/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394424/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394425/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394426/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394427/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394428/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394429/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394430/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394431/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394432/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394433/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394434/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394435/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394436/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394437/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394438/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394448/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394449/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394450/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394451/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394452/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394453/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394454/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394455/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394456/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394457/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394458/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394459/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394460/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394461/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394462/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394463/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394464/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394465/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394466/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394467/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394468/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394469/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394470/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394471/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394472/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394473/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394474/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394475/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394478/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394479/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394480/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394481/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394482/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394483/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394484/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394485/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394486/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394487/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394488/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394489/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394490/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394491/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394492/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394493/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394494/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394495/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394496/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394497/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394498/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394499/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394500/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394501/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394502/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394503/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394504/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394505/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394506/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394507/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394508/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394509/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394510/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394511/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394512/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394513/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394514/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394515/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394516/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394517/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394518/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394519/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394520/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394521/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394522/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394523/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394524/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394525/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394526/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394527/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394528/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394529/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394530/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394531/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394532/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394533/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394534/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394535/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394536/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394537/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394538/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394539/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394540/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394541/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394542/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394543/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394544/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394545/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394546/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394547/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394548/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394549/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394550/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394551/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394552/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394553/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394554/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394555/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394556/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394557/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394558/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394559/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394560/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394561/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394598/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394599/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394600/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394601/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394602/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394603/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394604/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394605/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394606/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394607/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394608/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394609/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394610/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394611/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394612/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394613/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394614/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394615/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394616/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394617/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394618/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394619/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394620/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394658/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394659/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394660/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394661/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394662/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394663/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394664/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394665/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394666/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394667/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394668/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394669/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394670/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394671/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394672/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394673/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394674/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394675/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394676/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394677/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394678/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394679/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394680/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394777/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394778/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394779/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394780/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394781/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394782/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394783/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394784/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394785/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394786/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394787/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394788/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394789/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394790/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394791/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394792/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394793/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394794/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394795/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394796/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394797/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394798/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394799/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394800/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394801/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394802/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394803/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394804/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394805/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394806/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394807/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394808/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394809/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394810/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394811/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394812/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394813/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394814/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394815/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394816/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394817/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394818/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394819/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394820/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394821/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394822/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394823/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394824/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394825/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394826/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394827/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394828/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394829/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394830/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394831/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394832/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394833/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394834/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394835/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394836/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394837/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394838/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394839/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394840/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394841/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394842/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394843/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394844/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394845/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394885/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394886/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394887/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394888/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394889/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394890/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394891/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394892/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394893/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394894/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394895/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394896/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394897/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394898/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394899/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394900/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394901/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394902/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394903/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394904/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394905/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394906/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394907/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394908/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394909/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394910/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394911/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394912/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394913/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394914/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394915/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394916/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394917/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394918/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394919/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394920/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5394921/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395032/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395033/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395034/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395035/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395036/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395037/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395038/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395039/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395040/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395041/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395042/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395043/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395044/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395045/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395046/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395050/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395051/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395052/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395053/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395054/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395055/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395056/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395057/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395058/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395059/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395060/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395061/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395062/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395063/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395064/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395065/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395066/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395067/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395068/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395069/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395070/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395071/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395072/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395073/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395074/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395075/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395076/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395077/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395078/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395081/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395082/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395083/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395084/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395085/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395086/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395087/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395088/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395089/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395090/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395091/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395092/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395093/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395094/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395095/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395096/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395097/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395098/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395099/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395100/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395101/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395102/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395103/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395104/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395105/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395106/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395107/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395108/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395109/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395110/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395111/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395112/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395113/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395114/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395115/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395116/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395117/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395118/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395119/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395120/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395121/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395122/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395123/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395124/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395125/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395126/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395127/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395128/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395129/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395130/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395131/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395132/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395133/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395134/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395135/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395136/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395137/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395138/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395139/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395140/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395141/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395142/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395143/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395144/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395145/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395146/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395147/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395148/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395149/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395150/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395152/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395153/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395154/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395155/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395156/expression
# ...
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395233/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395234/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395235/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395462/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395463/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395464/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395465/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395466/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395467/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395468/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395469/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395470/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395471/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395472/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395473/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395474/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395475/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395476/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395477/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395478/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395479/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395480/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395481/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395482/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395483/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395484/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395485/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395486/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395487/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395488/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395489/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395490/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395491/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395492/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395493/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395494/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395495/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395496/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395497/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395498/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395499/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395500/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395501/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395502/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395503/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395504/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395505/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395506/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395507/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395508/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395509/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395510/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395511/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395512/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395513/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395514/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395515/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395516/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395517/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395518/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395519/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395520/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395521/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395522/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395523/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395525/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395526/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395527/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395528/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395529/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395530/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395531/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395532/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395533/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395534/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395535/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395536/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395537/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395538/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395539/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395540/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395541/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395542/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395543/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395544/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395545/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395546/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395547/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395548/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395549/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395550/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395551/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395552/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395553/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395554/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395555/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395556/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395557/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395558/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395559/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395560/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395561/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395562/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395563/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395564/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395565/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395566/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395567/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395568/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395569/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395570/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395571/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395572/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395573/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395574/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395575/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395576/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395594/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395595/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395596/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395597/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395598/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395599/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395600/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395601/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395602/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395603/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395604/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395605/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395606/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395607/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395608/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395609/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395610/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395611/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395612/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395613/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395614/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395615/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395616/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395617/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395618/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395619/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395620/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395621/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395622/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395623/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395624/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395625/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395626/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395627/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395628/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395629/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395630/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395631/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395632/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395633/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395634/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395635/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395636/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395637/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395638/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395639/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395640/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395641/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395642/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395643/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395644/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395645/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395646/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395704/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395705/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395706/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395707/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395708/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395760/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395761/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395762/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395763/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395764/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395765/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395766/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395767/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395768/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395769/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395770/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395771/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395772/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395773/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395774/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395775/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395776/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395777/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395778/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395779/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395780/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395781/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395782/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395783/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395784/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395785/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395786/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395787/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395788/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395789/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395790/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395791/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395792/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395793/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395794/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395795/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395796/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395797/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395798/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395799/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395800/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395801/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395802/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395803/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395804/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395805/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395806/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395807/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395808/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395809/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395810/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395811/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395812/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395813/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395814/expression
# http://lblod.data.gift/vocabularies/vmm/actieplan/5395815/expression

# %% [markdown]
# ## 8. Codelist evaluation job
#
# Create and trigger a codelist evaluation job targeting expression URIs from the
# deliveries inserted above. The pipeline flow is:
#
# ```text
# singleton-job → evaluation-split-tasks → annotate
# ```

# %%
import uuid
import subprocess
from datetime import datetime, timezone

JOBS_GRAPH = HARVESTING_GRAPH

JOB_OPERATION_EVALUATION = (
    "http://lblod.data.gift/id/jobs/concept/"
    "JobOperation/codelist-matching/evaluation"
)
TASK_OPERATION_SINGLETON = (
    "http://lblod.data.gift/id/jobs/concept/"
    "TaskOperation/singleton-job"
)
STATUS_BUSY = "http://redpencil.data.gift/id/concept/JobStatus/busy"
STATUS_SCHEDULED = "http://redpencil.data.gift/id/concept/JobStatus/scheduled"
STATUS_SUCCESS = "http://redpencil.data.gift/id/concept/JobStatus/success"
SELF_SERVICE_CREATOR = "http://lblod.data.gift/services/job-self-service"
TEXT_PROPERTY_PATH = "<https://data.europarl.europa.eu/def/epvoc#expressionContent>"

DOCKER_NETWORK = "app-vmm_default"

JOB_PREFIXES = PREFIXES + "\n" + """
PREFIX mu:    <http://mu.semte.ch/vocabularies/core/>
PREFIX adms:  <http://www.w3.org/ns/adms#>
PREFIX task:  <http://redpencil.data.gift/vocabularies/tasks/>
PREFIX cogs:  <http://vocab.deri.ie/cogs#>
PREFIX nfo:   <http://www.semanticdesktop.org/ontologies/2007/03/22/nfo#>
PREFIX ext:   <http://mu.semte.ch/vocabularies/ext/>
PREFIX sh:    <http://www.w3.org/ns/shacl#>
""".strip()


def rdf_string(value: str) -> str:
    """Encode a Python string as a SPARQL-compatible quoted literal."""
    return json.dumps(value, ensure_ascii=False)


def utc_timestamp() -> str:
    return (
        datetime.now(timezone.utc)
        .isoformat(timespec="milliseconds")
        .replace("+00:00", "Z")
    )


def send_delta(service_url: str, delta_payload: list[dict]) -> str:
    """Send a delta notification to a service via the docker network."""
    cmd = [
        "docker", "run", "--rm", "--network", DOCKER_NETWORK,
        "curlimages/curl:latest",
        "-s", "-o", "/dev/null", "-w", "%{http_code}",
        "-X", "POST", "-H", "Content-Type: application/json",
        "-d", json.dumps(delta_payload),
        service_url,
    ]
    proc = subprocess.run(cmd, capture_output=True, text=True, timeout=60)
    return proc.stdout.strip()


print("Codelist evaluation helpers loaded.")
# Out:
# Codelist evaluation helpers loaded.

# %%
def create_codelist_evaluation_job(
    *,
    expression_uris: list[str],
    concept_scheme_uri: str,
    expressions_graph: str = PUBLIC_GRAPH,
    confidence_threshold: float = 0,
    text_property_path: str = TEXT_PROPERTY_PATH,
) -> dict[str, str]:
    """
    Create a codelist evaluation job targeting one or more existing expressions.

    Mirrors the frontend: creates a SHACL NodeShape with sh:targetNode entries
    for each expression, then creates the job and initial singleton task.
    The job-controller pipeline handles the rest:
      singleton-job \u2192 evaluation-split-tasks \u2192 annotate
    """
    if not expression_uris:
        raise ValueError("At least one expression URI is required.")

    job_uuid = str(uuid.uuid4())
    task_uuid = str(uuid.uuid4())
    shape_uuid = str(uuid.uuid4())
    container_uuid = str(uuid.uuid4())

    job_uri = f"http://data.lblod.info/id/jobs/{job_uuid}"
    task_uri = f"http://data.lblod.info/id/tasks/{task_uuid}"
    shape_uri = f"http://data.lblod.info/id/node-shapes/{shape_uuid}"
    container_uri = f"http://data.lblod.info/id/data-containers/{container_uuid}"

    timestamp = utc_timestamp()

    target_nodes = " ;\n          ".join(
        f"sh:targetNode <{u}>" for u in expression_uris
    )

    insert_query = f"""
    {JOB_PREFIXES}
    INSERT DATA {{
      GRAPH <{JOBS_GRAPH}> {{
        <{shape_uri}>
          a sh:NodeShape ;
          mu:uuid {rdf_string(shape_uuid)} ;
          {target_nodes} .

        <{job_uri}>
          a cogs:Job, ext:AnnotationJob ;
          mu:uuid {rdf_string(job_uuid)} ;
          adms:status <{STATUS_BUSY}> ;
          task:operation <{JOB_OPERATION_EVALUATION}> ;
          dct:creator <{SELF_SERVICE_CREATOR}> ;
          dct:created "{timestamp}"^^xsd:dateTime ;
          dct:modified "{timestamp}"^^xsd:dateTime ;
          ext:codelist <{concept_scheme_uri}> ;
          ext:graphForTargets <{expressions_graph}> ;
          ext:shapeForTargets <{shape_uri}> ;
          ext:propertyPathForText {rdf_string(text_property_path)} ;
          ext:confidenceThreshold "{confidence_threshold}"^^xsd:decimal .

        <{task_uri}>
          a task:Task ;
          mu:uuid {rdf_string(task_uuid)} ;
          adms:status <{STATUS_SCHEDULED}> ;
          task:operation <{TASK_OPERATION_SINGLETON}> ;
          task:index "0" ;
          dct:isPartOf <{job_uri}> ;
          task:inputContainer <{container_uri}> ;
          dct:created "{timestamp}"^^xsd:dateTime ;
          dct:modified "{timestamp}"^^xsd:dateTime .

        <{container_uri}>
          a nfo:DataContainer ;
          mu:uuid {rdf_string(container_uuid)} .
      }}
    }}
    """

    sparql_update(insert_query)

    print(f"Job:   {job_uri}")
    print(f"Task:  {task_uri}")
    print(f"Shape: {shape_uri} ({len(expression_uris)} target expressions)")

    return {
        "job_uuid": job_uuid,
        "task_uuid": task_uuid,
        "job": job_uri,
        "task": task_uri,
        "shape": shape_uri,
        "container": container_uri,
    }


def trigger_job_pipeline(task_uuid: str, container_uri: str) -> None:
    """
    Trigger the codelist evaluation pipeline.

    The harvest_singleton-job service only handles harvesting tasks (with
    collections/remote data objects). For codelist evaluation jobs, we:
    1. Advance the singleton task to 'success' ourselves
    2. Notify the job-controller so it creates the next task (evaluation-split-tasks)
    3. The annotation-job-splitter and codelist-labeling pick it up from there
    """
    task_uri = f"http://data.lblod.info/id/tasks/{task_uuid}"

    # 1. Mark singleton task as success
    update_query = f"""
    {JOB_PREFIXES}
    DELETE {{
      GRAPH <{JOBS_GRAPH}> {{
        <{task_uri}> adms:status ?oldStatus ;
                     dct:modified ?oldModified .
      }}
    }}
    INSERT {{
      GRAPH <{JOBS_GRAPH}> {{
        <{task_uri}> adms:status <{STATUS_SUCCESS}> ;
                     dct:modified "{utc_timestamp()}"^^xsd:dateTime ;
                     task:resultsContainer <{container_uri}> .
      }}
    }}
    WHERE {{
      GRAPH <{JOBS_GRAPH}> {{
        <{task_uri}> adms:status ?oldStatus .
        OPTIONAL {{ <{task_uri}> dct:modified ?oldModified . }}
      }}
    }}
    """
    sparql_update(update_query)
    print(f"Singleton task {task_uuid} \u2192 success")

    # 2. Notify job-controller (creates evaluation-split-tasks)
    delta = [{
        "inserts": [{
            "subject": {"type": "uri", "value": task_uri},
            "predicate": {"type": "uri", "value": "http://www.w3.org/ns/adms#status"},
            "object": {"type": "uri", "value": STATUS_SUCCESS},
        }],
        "deletes": [{
            "subject": {"type": "uri", "value": task_uri},
            "predicate": {"type": "uri", "value": "http://www.w3.org/ns/adms#status"},
            "object": {"type": "uri", "value": STATUS_SCHEDULED},
        }],
    }]

    status = send_delta("http://job-controller/delta", delta)
    print(f"job-controller notified: HTTP {status}")

    # 3. Also notify annotation-job-splitter
    import time
    time.sleep(2)  # brief wait for job-controller to create next task
    scheduled_delta = [{
        "inserts": [{
            "subject": {"type": "uri", "value": "urn:placeholder"},
            "predicate": {"type": "uri", "value": "http://www.w3.org/ns/adms#status"},
            "object": {"type": "uri", "value": STATUS_SCHEDULED},
        }],
        "deletes": [],
    }]
    status = send_delta("http://annotation-job-splitter/delta", scheduled_delta)
    print(f"annotation-job-splitter notified: HTTP {status}")


print("Job creation functions defined.")
# Out:
# Job creation functions defined.

# %%
# Select a range of deliveries whose expressions to target.
start_index = 0
end_index = 3000


# Create the job
result = create_codelist_evaluation_job(
    expression_uris=all_unprocessed_actieplan_uris[start_index:end_index],
    concept_scheme_uri=CODELIST_URI,
)
# Out:
# Job:   http://data.lblod.info/id/jobs/e6f8a5a9-d2ea-4226-aecd-1cefe1d3dec6
# Task:  http://data.lblod.info/id/tasks/a991a102-226c-4f55-8750-fbba643e4d59
# Shape: http://data.lblod.info/id/node-shapes/f6d186bc-b8e4-47aa-8909-35ae8e349d33 (3000 target expressions)

# %%
# Trigger the codelist evaluation pipeline.
# The harvest_singleton-job service only handles harvesting tasks,
# so for codelist jobs we advance the singleton task ourselves and
# let the job-controller take over.
trigger_job_pipeline(result["task_uuid"], result["container"])
# Out:
# Singleton task a991a102-226c-4f55-8750-fbba643e4d59 → success
# job-controller notified: HTTP 200
# annotation-job-splitter notified: HTTP 200

# %% [markdown]
# # Delete annotations linked to "vmm:Actieplan" expression instances

# %%
# Delete annotations linked to "vmm:Actieplan" expression instances.
# Works are in the public graph; annotations are in the public/pdf graph.

query = """
PREFIX eli: <http://data.europa.eu/eli/ontology#>
PREFIX vmm: <http://lblod.data.gift/vocabularies/vmm/>
PREFIX oa:  <http://www.w3.org/ns/oa#>

DELETE {
  GRAPH <http://mu.semte.ch/graphs/public/pdf> {
    # ?annotation ?p ?o .
    # ?s ?p2 ?annotation .
  }
}
WHERE {
  GRAPH <http://mu.semte.ch/graphs/public> {
    # ?work
      eli:work_type vmm:Actieplan ;
      eli:is_realized_by ?expression .
  }

  GRAPH <http://mu.semte.ch/graphs/public/pdf> {
    # ?annotation a oa:Annotation ;
                oa:hasTarget ?expression .
    OPTIONAL { ?annotation ?p ?o . }
    OPTIONAL { ?s ?p2 ?annotation . }
  }
}
"""

sparql_update(query)
